# %% [markdown]
# # Sports Betting Data Cleaning and Basic Data Driven Strategy #1

# %% [markdown]
# ### Package Imports

# %%
from OddsJamClient import OddsJamClient;
from dotenv import load_dotenv
import os, requests, datetime, json
import pandas as pd

# %% [markdown]
# ### Load Env Vars

# %%
load_dotenv()
ODDSJAM_API_KEY = os.getenv("ODDSJAM_API_KEY")

# %% [markdown]
# ### Initialize Clients

# %%
Client = OddsJamClient(ODDSJAM_API_KEY);
Client.UseV2();

# %% [markdown]
# ### Get Games For Today

# %%
def get_games_from_league_as_dataframe(league="nba", sport="basketball", game_date=None):
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/games'
    
    # Set up the headers with the API key and content type
    headers = {
        # 'x-api-key': ODDSJAM_API_KEY,
        'Content-Type': 'application/json'
    }

    if not game_date : 
        game_date = datetime.datetime.now().strftime('%Y-%m-%d')
    else:
        # Parse the string into a datetime object
        parsed_date = datetime.datetime.strptime(game_date, '%m/%d/%Y')
        # Format the datetime object to the desired string format
        game_date = parsed_date.strftime('%Y-%m-%d')

    
    # Set up the data payload with the parameters
    data = {
        'league': league,
        'sport': sport,
        "include_team_info": True,
        "key": ODDSJAM_API_KEY,
        "game_date": game_date
    }
    
    # Make the POST request to the API
    response = requests.get(end_point, headers=headers, params=data)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Here you would typically convert the response to a DataFrame
        df = pd.DataFrame(response.json()["data"])
        # update the time
        df['start_date'] = pd.to_datetime(df['start_date']).dt.strftime('%Y-%m-%d %H:%M:%S')
        df = df.sort_values(by='start_date').reset_index(drop=True)
        # Now, we extract the team ids from the home_team_info and away_team_info dictionaries
        # and then drop these columns from the DataFrame
        df['home_team_id'] = df['home_team_info'].apply(lambda x: x['id'])
        df['away_team_id'] = df['away_team_info'].apply(lambda x: x['id'])

        # Drop the now-redundant '_team_info' columns
        df = df.drop(columns=['home_team_info', 'away_team_info'])
        return df
    else:
        print(f"Error: {response.status_code}")
        # You could also handle errors here

# %%
games_df = get_games_from_league_as_dataframe(league="NBA", sport="basketball")

# %%
display(games_df)
# Out:
#                        id           start_date             home_team  \
# 0  19957-14251-2024-01-26  2024-01-26 19:00:00         Atlanta Hawks
# 1  32825-24860-2024-01-26  2024-01-26 19:00:00        Indiana Pacers
# 2  35142-17844-2024-01-26  2024-01-26 19:00:00     Charlotte Hornets
# 3  27843-35775-2024-01-26  2024-01-26 19:30:00       Toronto Raptors
# 4  11464-12967-2024-01-26  2024-01-26 20:00:00       Milwaukee Bucks
# 5  22796-30354-2024-01-26  2024-01-26 20:00:00     Memphis Grizzlies
# 6  86230-19432-2024-01-26  2024-01-26 20:00:00  New Orleans Pelicans
# 7  38874-32634-2024-01-26  2024-01-26 21:30:00     San Antonio Spurs
#
#                 away_team  is_live  is_popular tournament    status  \
# 0        Dallas Mavericks    False       False       None  unplayed
# 1            Phoenix Suns    False       False       None  unplayed
# 2         Houston Rockets    False       False       None  unplayed
# 3    Los Angeles Clippers    False       False       None  unplayed
# 4     Cleveland Cavaliers    False       False       None  unplayed
# 5           Orlando Magic    False       False       None  unplayed
# 6   Oklahoma City Thunder    False       False       None  unplayed
# 7  Portland Trail Blazers    False       False       None  unplayed
#
#         sport league  home_team_id  away_team_id
# 0  basketball    NBA  B59C1C735494  7165DAB9CAE4
# 1  basketball    NBA  F342C875E571  9BF9A5FD18B1
# 2  basketball    NBA  C65360931346  DF2D9E9E8E20
# 3  basketball    NBA  417F4FFF4625  3E1EA77686B9
# 4  basketball    NBA  14682EF45C4D  D5348BDFEBCC
# 5  basketball    NBA  2C653B0A5BBF  CC72CD00EB95
# 6  basketball    NBA  6C595835C85B  D8EC6878976A
# 7  basketball    NBA  E89F51275352  0054C2679F77

# %% [markdown]
# ### Segment The Games Into Sessions
# - Sessions are defined by games grouped together that start within 2 hours of each other
# - no two sessions will share the same game; they're all exclusive sessions.

# %%
def segment_games_into_sessions(games_df):
    # Ensure start_date is a datetime
    games_df['start_date'] = pd.to_datetime(games_df['start_date'])
    
    # Sort the games by start time
    sorted_games_df = games_df.sort_values(by='start_date').reset_index(drop=True)
    
    # List to hold all game sessions
    sessions = []
    # Temporary list to store games for the current session
    current_session = []
    # Start time of the current session
    session_start = None
    
    for _, game in sorted_games_df.iterrows():
        game_start = game['start_date']
        
        # If current session is empty or game starts within 2 hours of the session start
        if not current_session or (game_start - session_start).total_seconds() <= 2 * 3600:
            # Add game to current session
            current_session.append(game)
            # If this is the first game in the session, set the session start time
            if not session_start:
                session_start = game_start
        else:
            # If game starts more than 2 hours after the session start, save and reset the session
            sessions.append(current_session)
            current_session = [game]
            session_start = game_start
    
    # Add the last session if it exists
    if current_session:
        sessions.append(current_session)
    
    # Convert sessions to DataFrame list for better handling
    session_dfs = [pd.DataFrame(session) for session in sessions]
    
    return session_dfs

# %%
# Example usage:
# Assuming games_df is your DataFrame containing the games information.
segmented_sessions = segment_games_into_sessions(games_df)

# You can then access each session DataFrame with segmented_sessions[0], segmented_sessions[1], etc.
len(segmented_sessions)
# Out:
# 2

# %% [markdown]
# ### Get Players From A Specific Team

# %%
def get_players_from_specific_team(team_id: str, league="nba", sport="basketball") -> pd.DataFrame:
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/players/list'
    
    # Set up the headers with the API key
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Set up the parameters with the team_id
    params = {
        'team': team_id,
        'page': 1,
        # "league": league,
        # "sport": sport,
        'key': ODDSJAM_API_KEY
    }
    
    # Make the GET request to the API
    response = requests.get(end_point, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        data = response.json()["data"]
        df = pd.DataFrame(data)
        print(f'total pages: {response.json()["total_pages"]}')
        return df
    else:
        print(f"Error: {response.status_code}")
        return pd.DataFrame()

# %% [markdown]
# ### Testing That The Functionality Works As Envisioned
# * Need to get the game_id from the segmented_sessions

# %%
display(segmented_sessions[0])
# Out:
#                        id          start_date             home_team  \
# 0  19957-14251-2024-01-26 2024-01-26 19:00:00         Atlanta Hawks
# 1  32825-24860-2024-01-26 2024-01-26 19:00:00        Indiana Pacers
# 2  35142-17844-2024-01-26 2024-01-26 19:00:00     Charlotte Hornets
# 3  27843-35775-2024-01-26 2024-01-26 19:30:00       Toronto Raptors
# 4  11464-12967-2024-01-26 2024-01-26 20:00:00       Milwaukee Bucks
# 5  22796-30354-2024-01-26 2024-01-26 20:00:00     Memphis Grizzlies
# 6  86230-19432-2024-01-26 2024-01-26 20:00:00  New Orleans Pelicans
#
#                away_team  is_live  is_popular tournament    status  \
# 0       Dallas Mavericks    False       False       None  unplayed
# 1           Phoenix Suns    False       False       None  unplayed
# 2        Houston Rockets    False       False       None  unplayed
# 3   Los Angeles Clippers    False       False       None  unplayed
# 4    Cleveland Cavaliers    False       False       None  unplayed
# 5          Orlando Magic    False       False       None  unplayed
# 6  Oklahoma City Thunder    False       False       None  unplayed
#
#         sport league  home_team_id  away_team_id
# 0  basketball    NBA  B59C1C735494  7165DAB9CAE4
# 1  basketball    NBA  F342C875E571  9BF9A5FD18B1
# 2  basketball    NBA  C65360931346  DF2D9E9E8E20
# 3  basketball    NBA  417F4FFF4625  3E1EA77686B9
# 4  basketball    NBA  14682EF45C4D  D5348BDFEBCC
# 5  basketball    NBA  2C653B0A5BBF  CC72CD00EB95
# 6  basketball    NBA  6C595835C85B  D8EC6878976A

# %%
get_players_from_specific_team(segmented_sessions[1].iloc[0]['home_team_id'])
# Out:
# total pages: 1
#               id            player_name first_name       last_name  \
# 0   7959261438C7           Blake Wesley      Blake          Wesley
# 1   97294E569CB7             Cedi Osman       Cedi           Osman
# 2   CD99BB67884D         Charles Bassey    Charles          Bassey
# 3   E10320F559B1         David Duke Jr.      David        Duke Jr.
# 4   804B793FEEDB          Devin Vassell      Devin         Vassell
# 5   AACF1CBA1094        Devonte' Graham   Devonte'          Graham
# 6   17624A972445        Dominick Barlow   Dominick          Barlow
# 7   CA04B2FDE9C2         Doug McDermott       Doug       McDermott
# 8   80FFC6ED3456          Jeremy Sochan     Jeremy          Sochan
# 9   99318830CCC3      Julian Champagnie     Julian      Champagnie
# 10  F34EFECEA2DA         Keldon Johnson     Keldon         Johnson
# 11  98A54A13BDB9         Malaki Branham     Malaki         Branham
# 12  B904B59F7593         Mamadi Diakite     Mamadi         Diakite
# 13  9FC0FB04CE9A  Sandro Mamukelashvili     Sandro  Mamukelashvili
# 14  E31B2A490250           Sidy Cissoko       Sidy         Cissoko
# 15  D45700C1F1BD              Tre Jones        Tre           Jones
# 16  ECE70FF020E8      Victor Wembanyama     Victor      Wembanyama
# 17  00238C40718B           Zach Collins       Zach         Collins
#
#             team_name       team_id number position age height  weight  \
# 0   San Antonio Spurs  E89F51275352     14       SG  21     77     181
# 1   San Antonio Spurs  E89F51275352     16       SG  29     79     215
# 2   San Antonio Spurs  E89F51275352     28        C  24     83     235
# 3   San Antonio Spurs  E89F51275352      7       SG  25     76     205
# 4   San Antonio Spurs  E89F51275352     24       SG  24     79     194
# 5   San Antonio Spurs  E89F51275352      4       SG  29     73     185
# 6   San Antonio Spurs  E89F51275352     26       SF  21     81     214
# 7   San Antonio Spurs  E89F51275352     17       PF  32     79     225
# 8   San Antonio Spurs  E89F51275352     10       PF  21     81     230
# 9   San Antonio Spurs  E89F51275352     30       SF  23     80     215
# 10  San Antonio Spurs  E89F51275352      3       SF  25     77     211
# 11  San Antonio Spurs  E89F51275352     22       SG  21     77     180
# 12  San Antonio Spurs  E89F51275352     29       PF  27     81     224
# 13  San Antonio Spurs  E89F51275352     54        C  25     83     240
# 14  San Antonio Spurs  E89F51275352     25       SF  20     80     200
# 15  San Antonio Spurs  E89F51275352     33       PG  24     75     185
# 16  San Antonio Spurs  E89F51275352      1       PF  20     88     210
# 17  San Antonio Spurs  E89F51275352     23       PF  27     83     235
#
#     is_active       sport league
# 0        True  basketball    NBA
# 1        True  basketball    NBA
# 2        True  basketball    NBA
# 3        True  basketball    NBA
# 4        True  basketball    NBA
# 5        True  basketball    NBA
# 6        True  basketball    NBA
# 7        True  basketball    NBA
# 8        True  basketball    NBA
# 9        True  basketball    NBA
# 10       True  basketball    NBA
# 11       True  basketball    NBA
# 12       True  basketball    NBA
# 13       True  basketball    NBA
# 14       True  basketball    NBA
# 15       True  basketball    NBA
# 16       True  basketball    NBA
# 17       True  basketball    NBA

# %%
temp = get_players_from_specific_team(segmented_sessions[1].iloc[0]['away_team_id'])
# Out:
# total pages: 1

# %%
temp
# Out:
#               id       player_name first_name  last_name  \
# 0   A08DF5DBBEE9   Anfernee Simons   Anfernee     Simons
# 1   54818F8E80E9     Deandre Ayton    Deandre      Ayton
# 2   98CCB5584896        Duop Reath       Duop      Reath
# 3   0B46AA021772        Ibou Badji       Ibou      Badji
# 4   677724637AF2     Jabari Walker     Jabari     Walker
# 5   628DC7694C25      Jerami Grant     Jerami      Grant
# 6   DFCA987B0935     Justin Minaya     Justin     Minaya
# 7   0E43E155B0D5       Kris Murray       Kris     Murray
# 8   D580A3FB8020   Malcolm Brogdon    Malcolm    Brogdon
# 9   805BF30F4B70  Matisse Thybulle    Matisse   Thybulle
# 10  9429EDA9E051       Moses Brown      Moses      Brown
# 11  CE0B782BFD67      Rayan Rupert      Rayan     Rupert
# 12  61A9758D002F   Robert Williams     Robert   Williams
# 13  C3F1E061CAD6   Scoot Henderson      Scoot  Henderson
# 14  D53995324E8F    Shaedon Sharpe    Shaedon     Sharpe
# 15  D210661887F5        Taze Moore       Taze      Moore
# 16  DD05A1E94051    Toumani Camara    Toumani     Camara
#
#                  team_name       team_id number position age height  weight  \
# 0   Portland Trail Blazers  0054C2679F77      1       SG  25     75     185
# 1   Portland Trail Blazers  0054C2679F77      2        C  26     83     250
# 2   Portland Trail Blazers  0054C2679F77     26        C  28     83     244
# 3   Portland Trail Blazers  0054C2679F77     41        C  22     84     240
# 4   Portland Trail Blazers  0054C2679F77     34       PF  22     81     215
# 5   Portland Trail Blazers  0054C2679F77      9       PF  30     80     220
# 6   Portland Trail Blazers  0054C2679F77     24       SF  25     79     210
# 7   Portland Trail Blazers  0054C2679F77      8       SF  24     80     220
# 8   Portland Trail Blazers  0054C2679F77     11       PG  32     77     224
# 9   Portland Trail Blazers  0054C2679F77      4       SF  27     77     200
# 10  Portland Trail Blazers  0054C2679F77     10        C  25     86     245
# 11  Portland Trail Blazers  0054C2679F77     72       SG  20     79     185
# 12  Portland Trail Blazers  0054C2679F77     35        C  27     80     240
# 13  Portland Trail Blazers  0054C2679F77     00       PG  20     74     195
# 14  Portland Trail Blazers  0054C2679F77     17       SG  21     78     200
# 15  Portland Trail Blazers  0054C2679F77     76       SF  26     77     195
# 16  Portland Trail Blazers  0054C2679F77     33       SF  24     80     220
#
#     is_active       sport league
# 0        True  basketball    NBA
# 1        True  basketball    NBA
# 2        True  basketball    NBA
# 3        True  basketball    NBA
# 4        True  basketball    NBA
# 5        True  basketball    NBA
# 6        True  basketball    NBA
# 7        True  basketball    NBA
# 8        True  basketball    NBA
# 9        True  basketball    NBA
# 10       True  basketball    NBA
# 11       True  basketball    NBA
# 12       True  basketball    NBA
# 13       True  basketball    NBA
# 14       True  basketball    NBA
# 15       True  basketball    NBA
# 16       True  basketball    NBA

# %% [markdown]
# ### Get All Available Player Props For Each Team, Given There's A PrizePicks Line

# %%
def get_all_player_odds(player_ids: list, sportsbooks: list, league="nba", sport="basketball"):
    all_data = []
    # Loop through the player_ids in steps of 5
    for i in range(0, len(player_ids), 3):
        batch_ids = player_ids[i:i+3]
        params = {
            'player_id': batch_ids,
            'sportsbook': sportsbooks,
            'league': league,
            'sport': sport,
            'key': ODDSJAM_API_KEY
        }
        response = requests.get('https://api-external.oddsjam.com/api/v2/game-odds', headers=headers, params=params)
        
        if response.status_code == 200:
            # Convert the JSON response to a DataFrame
            data = response.json()['data']
            df = pd.DataFrame(data)
            all_data.append(df)
        else:
            print(f"Error: {response.reason}")
            print(response.text)
            # Depending on your error handling preference, you may comment out the next line
            # to continue processing in case of an error, or leave it to stop the function.
            return pd.DataFrame() 

    # Concatenate all dataframes into a single dataframe
    final_df = pd.concat(all_data, ignore_index=True)
    return final_df

# %% [markdown]
# ### Test That The Function Pulls Odds Correctly

# %%
id_list = temp['id'].tolist()
display(id_list)
odds = get_player_odds(id_list[:5], ["PrizePicks", "Underdog Fantasy", "Pinnacle", "FanDuel", "Draftkings", "BetMGM"])
# Out:
# ['A08DF5DBBEE9',
#  '54818F8E80E9',
#  '98CCB5584896',
#  '0B46AA021772',
#  '677724637AF2',
#  '628DC7694C25',
#  'DFCA987B0935',
#  '0E43E155B0D5',
#  'D580A3FB8020',
#  '805BF30F4B70',
#  '9429EDA9E051',
#  'CE0B782BFD67',
#  '61A9758D002F',
#  'C3F1E061CAD6',
#  'D53995324E8F',
#  'D210661887F5',
#  'DD05A1E94051']

# %%
odds.shape
# Out:
# (1, 11)

# %%
books = odds.iloc[0].odds
books
# Out:
# [{'id': '38874-32634-2024-01-26:betmgm:first_basket:anfernee_simons',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons',
#   'price': 750.0,
#   'timestamp': 1706283745.4306633,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Basket',
#   'market': 'first_basket',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054986410--1239083334&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '38874-32634-2024-01-26:betmgm:first_basket:deandre_ayton',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton',
#   'price': 600.0,
#   'timestamp': 1706283745.4306633,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Basket',
#   'market': 'first_basket',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054986410--1239083335&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '38874-32634-2024-01-26:betmgm:first_basket:jabari_walker',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker',
#   'price': 900.0,
#   'timestamp': 1706283745.4306633,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Basket',
#   'market': 'first_basket',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054986410--1239083330&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:anfernee_simons_over_5_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 5.5',
#   'price': -120.0,
#   'timestamp': 1706293143.666962,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021092--1238986062&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 5.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:anfernee_simons_under_5_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 5.5',
#   'price': -110.0,
#   'timestamp': 1706304019.895126,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021092--1238986061&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 5.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:deandre_ayton_over_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 1.5',
#   'price': 110.0,
#   'timestamp': 1706304019.895126,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021514--1238984869&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:deandre_ayton_under_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 1.5',
#   'price': -145.0,
#   'timestamp': 1706304019.895126,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021514--1238984868&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:jabari_walker_over_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 1.5',
#   'price': 180.0,
#   'timestamp': 1706285650.0371494,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884142--1239360342&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_assists:jabari_walker_under_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 1.5',
#   'price': -250.0,
#   'timestamp': 1706284770.2578244,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Assists',
#   'market': 'player_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884142--1239360341&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:anfernee_simons_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': 375.0,
#   'timestamp': 1706285345.1239045,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021068--1238986110&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:anfernee_simons_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': -600.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021068--1238986109&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:deandre_ayton_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 0.5',
#   'price': -150.0,
#   'timestamp': 1706285595.291418,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021531--1238984835&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:deandre_ayton_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 0.5',
#   'price': 115.0,
#   'timestamp': 1706285565.5215504,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021531--1238984834&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:jabari_walker_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 0.5',
#   'price': 140.0,
#   'timestamp': 1706292803.4784892,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884167--1239360192&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_blocks:jabari_walker_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 0.5',
#   'price': -190.0,
#   'timestamp': 1706292803.4784892,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Blocks',
#   'market': 'player_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884167--1239360191&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:anfernee_simons_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': 700.0,
#   'timestamp': 1706292793.5298254,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021061--1238986124&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:anfernee_simons_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': -2000.0,
#   'timestamp': 1706285345.1239045,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021061--1238986123&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:deandre_ayton_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 0.5',
#   'price': -110.0,
#   'timestamp': 1706285560.0369065,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021534--1238984829&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:deandre_ayton_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 0.5',
#   'price': -125.0,
#   'timestamp': 1706285560.0369065,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021534--1238984828&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:jabari_walker_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 0.5',
#   'price': 250.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884169--1239360188&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_double_double:jabari_walker_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 0.5',
#   'price': -375.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Double Double',
#   'market': 'player_double_double',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884169--1239360187&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_made_threes:anfernee_simons_over_3_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 3.5',
#   'price': -120.0,
#   'timestamp': 1706285565.5215504,
#   'bet_points': 3.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Made Threes',
#   'market': 'player_made_threes',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021063--1238986120&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 3.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_made_threes:anfernee_simons_under_3_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 3.5',
#   'price': -110.0,
#   'timestamp': 1706285565.5215504,
#   'bet_points': 3.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Made Threes',
#   'market': 'player_made_threes',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021063--1238986119&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 3.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_made_threes:jabari_walker_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 0.5',
#   'price': -135.0,
#   'timestamp': 1706293153.745049,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Made Threes',
#   'market': 'player_made_threes',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884168--1239360190&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_made_threes:jabari_walker_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 0.5',
#   'price': 100.0,
#   'timestamp': 1706293153.745049,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Made Threes',
#   'market': 'player_made_threes',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884168--1239360189&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:anfernee_simons_over_24_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 24.5',
#   'price': -110.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 24.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021077--1238986092&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 24.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:anfernee_simons_under_24_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 24.5',
#   'price': -120.0,
#   'timestamp': 1706285655.2560809,
#   'bet_points': 24.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021077--1238986091&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 24.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:deandre_ayton_over_13_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 13.5',
#   'price': -120.0,
#   'timestamp': 1706285645.0187185,
#   'bet_points': 13.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021509--1238984879&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 13.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:deandre_ayton_under_13_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 13.5',
#   'price': -110.0,
#   'timestamp': 1706285645.0187185,
#   'bet_points': 13.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021509--1238984878&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 13.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:jabari_walker_over_10_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 10.5',
#   'price': -120.0,
#   'timestamp': 1706285560.0369065,
#   'bet_points': 10.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884165--1239360196&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 10.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points:jabari_walker_under_10_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 10.5',
#   'price': -110.0,
#   'timestamp': 1706285560.0369065,
#   'bet_points': 10.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points',
#   'market': 'player_points',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884165--1239360195&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 10.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:anfernee_simons_over_30_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 30.5',
#   'price': -110.0,
#   'timestamp': 1706285470.1872222,
#   'bet_points': 30.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021098--1238986050&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 30.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:anfernee_simons_under_30_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 30.5',
#   'price': -120.0,
#   'timestamp': 1706285470.1872222,
#   'bet_points': 30.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021098--1238986049&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 30.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:deandre_ayton_over_14_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 14.5',
#   'price': -130.0,
#   'timestamp': 1706304049.663284,
#   'bet_points': 14.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055022278--1238983293&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 14.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:deandre_ayton_under_14_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 14.5',
#   'price': 100.0,
#   'timestamp': 1706304024.8145108,
#   'bet_points': 14.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055022278--1238983292&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 14.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:jabari_walker_over_11_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 11.5',
#   'price': -125.0,
#   'timestamp': 1706292803.4784892,
#   'bet_points': 11.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054886139--1239355097&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_assists:jabari_walker_under_11_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 11.5',
#   'price': -105.0,
#   'timestamp': 1706285655.2560809,
#   'bet_points': 11.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Assists',
#   'market': 'player_points_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054886139--1239355096&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:anfernee_simons_over_27_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 27.5',
#   'price': -120.0,
#   'timestamp': 1706304024.8145108,
#   'bet_points': 27.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055179586--1238568124&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 27.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:anfernee_simons_under_27_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 27.5',
#   'price': -110.0,
#   'timestamp': 1706304024.8145108,
#   'bet_points': 27.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055179586--1238568123&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 27.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:deandre_ayton_over_23_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 23.5',
#   'price': -120.0,
#   'timestamp': 1706285390.0040922,
#   'bet_points': 23.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021540--1238984817&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 23.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:deandre_ayton_under_23_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 23.5',
#   'price': -110.0,
#   'timestamp': 1706285595.291418,
#   'bet_points': 23.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021540--1238984816&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 23.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:jabari_walker_over_18_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 18.5',
#   'price': -125.0,
#   'timestamp': 1706304030.2500303,
#   'bet_points': 18.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055179606--1238568084&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 18.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds:jabari_walker_under_18_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 18.5',
#   'price': -105.0,
#   'timestamp': 1706304030.2500303,
#   'bet_points': 18.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds',
#   'market': 'player_points_+_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055179606--1238568083&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 18.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:anfernee_simons_over_33_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 33.5',
#   'price': -120.0,
#   'timestamp': 1706285655.2560809,
#   'bet_points': 33.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055024599--1238976297&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 33.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:anfernee_simons_under_33_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 33.5',
#   'price': -110.0,
#   'timestamp': 1706285655.2560809,
#   'bet_points': 33.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055024599--1238976296&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 33.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:deandre_ayton_over_25_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 25.5',
#   'price': -110.0,
#   'timestamp': 1706292783.668001,
#   'bet_points': 25.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021549--1238984799&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 25.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:deandre_ayton_under_25_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 25.5',
#   'price': -120.0,
#   'timestamp': 1706293163.3486686,
#   'bet_points': 25.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021549--1238984798&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 25.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:jabari_walker_over_20_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 20.5',
#   'price': -105.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 20.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884171--1239360184&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 20.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_points_+_rebounds_+_assists:jabari_walker_under_20_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 20.5',
#   'price': -125.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 20.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Points + Rebounds + Assists',
#   'market': 'player_points_+_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884171--1239360183&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 20.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:anfernee_simons_over_3_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 3.5',
#   'price': -105.0,
#   'timestamp': 1706293153.745049,
#   'bet_points': 3.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021086--1238986074&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 3.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:anfernee_simons_under_3_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 3.5',
#   'price': -125.0,
#   'timestamp': 1706293153.745049,
#   'bet_points': 3.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021086--1238986073&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 3.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:deandre_ayton_over_10_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 10.5',
#   'price': 105.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 10.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021517--1238984863&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 10.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:deandre_ayton_under_10_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 10.5',
#   'price': -140.0,
#   'timestamp': 1706304009.7994578,
#   'bet_points': 10.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021517--1238984862&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 10.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:jabari_walker_over_8_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 8.5',
#   'price': 105.0,
#   'timestamp': 1706285555.4415476,
#   'bet_points': 8.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884159--1239360268&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 8.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds:jabari_walker_under_8_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 8.5',
#   'price': -140.0,
#   'timestamp': 1706285555.4415476,
#   'bet_points': 8.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds',
#   'market': 'player_rebounds',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884159--1239360267&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 8.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:anfernee_simons_over_9_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 9.5',
#   'price': 100.0,
#   'timestamp': 1706285470.1872222,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021109--1238986027&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:anfernee_simons_under_9_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 9.5',
#   'price': -130.0,
#   'timestamp': 1706304014.974338,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021109--1238986026&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:deandre_ayton_over_11_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 11.5',
#   'price': -125.0,
#   'timestamp': 1706293158.7725747,
#   'bet_points': 11.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021545--1238984807&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:deandre_ayton_under_11_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 11.5',
#   'price': -110.0,
#   'timestamp': 1706285565.5215504,
#   'bet_points': 11.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021545--1238984806&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:jabari_walker_over_9_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 9.5',
#   'price': -105.0,
#   'timestamp': 1706285085.2021344,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884170--1239360186&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_rebounds_+_assists:jabari_walker_under_9_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 9.5',
#   'price': -130.0,
#   'timestamp': 1706304019.895126,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884170--1239360185&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:anfernee_simons_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': -140.0,
#   'timestamp': 1706293158.7725747,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021083--1238986080&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:anfernee_simons_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': 105.0,
#   'timestamp': 1706285350.2022283,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021083--1238986079&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:deandre_ayton_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 0.5',
#   'price': -210.0,
#   'timestamp': 1706304019.895126,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021520--1238984857&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:deandre_ayton_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Under 0.5',
#   'price': 150.0,
#   'timestamp': 1706285560.0369065,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021520--1238984856&type=Single',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:jabari_walker_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Over 0.5',
#   'price': -145.0,
#   'timestamp': 1706285650.0371494,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884164--1239360198&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals:jabari_walker_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Jabari Walker Under 0.5',
#   'price': 105.0,
#   'timestamp': 1706285219.8805199,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1054884164--1239360197&type=Single',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals_+_blocks:anfernee_simons_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': -200.0,
#   'timestamp': 1706293158.7725747,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021100--1238986046&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals_+_blocks:anfernee_simons_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': 145.0,
#   'timestamp': 1706285555.4415476,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15236618-1055021100--1238986045&type=Single',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:betmgm:player_steals_+_blocks:deandre_ayton_over_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Deandre Ayton Over 1.5',
#   'price': -145.0,
#   'timestamp': 1706292803.4784892,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
# ...
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590463%231708937787_13L42648Q1-1801024777Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_rebounds_+_assists:deandre_ayton_under_11_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Under 11.5',
#   'price': -110.0,
#   'timestamp': 1706285556.931224,
#   'bet_points': 11.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590463%231708937788_15L42648Q1-1541943325Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 11.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_rebounds_+_assists:jabari_walker_over_9_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Over 9.5',
#   'price': -105.0,
#   'timestamp': 1706285586.8686795,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563294%231708733273_13L42648Q11940200365Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_rebounds_+_assists:jabari_walker_under_9_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Under 9.5',
#   'price': -125.0,
#   'timestamp': 1706285586.8686795,
#   'bet_points': 9.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Rebounds + Assists',
#   'market': 'player_rebounds_+_assists',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563294%231708733274_15L42648Q1-1909428335Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 9.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:anfernee_simons_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': -135.0,
#   'timestamp': 1706285331.93496,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590415%231708937617_13L42648Q1-2092032920Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:anfernee_simons_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': 105.0,
#   'timestamp': 1706285331.93496,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590415%231708937618_15L42648Q1437809812Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:deandre_ayton_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Over 0.5',
#   'price': -195.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590462%231708937781_13L42648Q1-2092032920Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:deandre_ayton_over_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Over 1.5',
#   'price': 230.0,
#   'timestamp': 1706312363.3415205,
#   'bet_points': 1.5,
#   'is_main': False,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590475%231708937823_13L42648Q12102868148Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:deandre_ayton_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Under 0.5',
#   'price': 150.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590462%231708937782_15L42648Q1437809812Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:jabari_walker_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Over 0.5',
#   'price': -135.0,
#   'timestamp': 1706264550.352633,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563296%231708733275_13L42648Q1-2092032920Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals:jabari_walker_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Under 0.5',
#   'price': 105.0,
#   'timestamp': 1706264550.352633,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals',
#   'market': 'player_steals',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563296%231708733276_15L42648Q1437809812Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:anfernee_simons_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Over 0.5',
#   'price': -190.0,
#   'timestamp': 1706285331.93496,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590413%231708937613_13L42648Q1928931368Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:anfernee_simons_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Under 0.5',
#   'price': 145.0,
#   'timestamp': 1706285331.93496,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590413%231708937614_15L42648Q1-301757365Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:deandre_ayton_over_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Over 1.5',
#   'price': -140.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590467%231708937791_13L42648Q1-1531230057Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:deandre_ayton_under_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Under 1.5',
#   'price': 110.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590467%231708937792_15L42648Q1432774686Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:jabari_walker_over_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Over 1.5',
#   'price': 150.0,
#   'timestamp': 1706284596.9277918,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563299%231708733281_13L42648Q1-1531230057Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_steals_+_blocks:jabari_walker_under_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Under 1.5',
#   'price': -195.0,
#   'timestamp': 1706284596.9277918,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Steals + Blocks',
#   'market': 'player_steals_+_blocks',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563299%231708733282_15L42648Q1432774686Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:anfernee_simons_over_2_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Over 2.5',
#   'price': -110.0,
#   'timestamp': 1706304007.6609957,
#   'bet_points': 2.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590404%231708937592_13L42648Q1-1784025130Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'over',
#   'selection_points': 2.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:anfernee_simons_under_2_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Anfernee Simons Under 2.5',
#   'price': -120.0,
#   'timestamp': 1706304007.6609957,
#   'bet_points': 2.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590404%231708937593_15L42648Q1-1763567857Q20',
#   'player_id': 'A08DF5DBBEE9',
#   'selection': 'Anfernee Simons',
#   'normalized_selection': 'anfernee_simons',
#   'selection_line': 'under',
#   'selection_points': 2.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:deandre_ayton_over_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Over 1.5',
#   'price': -130.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590456%231708937779_13L42648Q11523463610Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:deandre_ayton_under_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Deandre Ayton Under 1.5',
#   'price': 100.0,
#   'timestamp': 1706285376.8493774,
#   'bet_points': 1.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181590456%231708937780_15L42648Q1864564274Q20',
#   'player_id': '54818F8E80E9',
#   'selection': 'Deandre Ayton',
#   'normalized_selection': 'deandre_ayton',
#   'selection_line': 'under',
#   'selection_points': 1.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:jabari_walker_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Over 0.5',
#   'price': -230.0,
#   'timestamp': 1706284611.9361172,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563286%231708733252_13L42648Q1330165043Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '38874-32634-2024-01-26:draftkings:player_turnovers:jabari_walker_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Jabari Walker Under 0.5',
#   'price': 175.0,
#   'timestamp': 1706284611.9361172,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Turnovers',
#   'market': 'player_turnovers',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/30028720?outcomes=0QA181563286%231708733253_15L42648Q1-1267642995Q20',
#   'player_id': '677724637AF2',
#   'selection': 'Jabari Walker',
#   'normalized_selection': 'jabari_walker',
#   'selection_line': 'under',
#   'selection_points': 0.5}]

# %%
books_df = pd.DataFrame(books)
display(books_df.head())
print(books_df.shape)
# Out:
#                                                   id sports_book_name  \
# 0  38874-32634-2024-01-26:betmgm:first_basket:anf...           BetMGM
# 1  38874-32634-2024-01-26:betmgm:first_basket:dea...           BetMGM
# 2  38874-32634-2024-01-26:betmgm:first_basket:jab...           BetMGM
# 3  38874-32634-2024-01-26:betmgm:player_assists:a...           BetMGM
# 4  38874-32634-2024-01-26:betmgm:player_assists:a...           BetMGM
#
#                         name  price     timestamp  bet_points  is_main  \
# 0            Anfernee Simons  750.0  1.706284e+09         NaN     True
# 1              Deandre Ayton  600.0  1.706284e+09         NaN     True
# 2              Jabari Walker  900.0  1.706284e+09         NaN     True
# 3   Anfernee Simons Over 5.5 -120.0  1.706293e+09         5.5     True
# 4  Anfernee Simons Under 5.5 -110.0  1.706304e+09         5.5     True
#
#    is_live     market_name          market  home_rotation_number  \
# 0    False    First Basket    first_basket                   NaN
# 1    False    First Basket    first_basket                   NaN
# 2    False    First Basket    first_basket                   NaN
# 3    False  Player Assists  player_assists                   NaN
# 4    False  Player Assists  player_assists                   NaN
#
#    away_rotation_number                                      deep_link_url  \
# 0                   NaN  https://sports.<STATE>.betmgm.com/en/sports?op...
# 1                   NaN  https://sports.<STATE>.betmgm.com/en/sports?op...
# 2                   NaN  https://sports.<STATE>.betmgm.com/en/sports?op...
# 3                   NaN  https://sports.<STATE>.betmgm.com/en/sports?op...
# 4                   NaN  https://sports.<STATE>.betmgm.com/en/sports?op...
#
#       player_id        selection normalized_selection selection_line  \
# 0  A08DF5DBBEE9  Anfernee Simons      anfernee_simons           None
# 1  54818F8E80E9    Deandre Ayton        deandre_ayton           None
# 2  677724637AF2    Jabari Walker        jabari_walker           None
# 3  A08DF5DBBEE9  Anfernee Simons      anfernee_simons           over
# 4  A08DF5DBBEE9  Anfernee Simons      anfernee_simons          under
#
#    selection_points
# 0               NaN
# 1               NaN
# 2               NaN
# 3               5.5
# 4               5.5
# (695, 18)

# %% [markdown]
# ### Create Cleaned Sportsbook Data Frame
# * Each row will have PrizePicks and show the odds and the line for a couple other highly trusted Sportsbooks.
# * This makes it seemless to compare PrizePicks Player Projections to the sentiment of the trusted market.

# %%
def filter_for_prizepicks(odds_df):
    # First, sort the DataFrame by the 'market' column, which acts as our unique key.
    sorted_odds_df = odds_df.sort_values(by='market')

    # Group by 'market' to organize our DataFrame into groups based on prediction types.
    grouped = sorted_odds_df.groupby('market')

    # Now, we will keep only the groups that contain at least one 'PrizePicks' entry.
    valid_groups = []
    for name, group in grouped:
        if 'PrizePicks' in group['sports_book_name'].values:
            valid_groups.append(group)
    if len(valid_groups) > 0:
        # Combine all valid groups back into a DataFrame.
        filtered_df = pd.concat(valid_groups)
        filtered_df = filtered_df.groupby(['market', 'sports_book_name']).apply(lambda x: x.reset_index(drop=True)).reset_index(drop=True)
    else:
        filtered_df = pd.DataFrame()
    
    return filtered_df

# %% [markdown]
# ### Testing the functionality

# %%
filtered_odds_df = filter_for_prizepicks(books_df)

# %%
filtered_odds_df
# Out:
#                id  sports_book_name                        name  price  \
# 0    62CCECD23CDF        PrizePicks   Anfernee Simons Over 18.5 -137.0
# 1    147F7DB13100        PrizePicks  Anfernee Simons Under 18.5 -137.0
# 2    DB05A279814F        PrizePicks     Deandre Ayton Over 15.5 -137.0
# 3    0960EC441208        PrizePicks    Deandre Ayton Under 15.5 -137.0
# 4    EABC944A657F        PrizePicks     Jabari Walker Over 11.5 -137.0
# ..            ...               ...                         ...    ...
# 578  4F51FEFE6F09        PrizePicks     Deandre Ayton Under 1.5 -137.0
# 579  39799625B337  Underdog Fantasy     Deandre Ayton Under 1.5 -137.0
# 580  E44A6C61B617  Underdog Fantasy      Deandre Ayton Over 1.5 -137.0
# 581  AF7587D74DF2  Underdog Fantasy   Anfernee Simons Under 2.5 -137.0
# 582  90B2CE143738  Underdog Fantasy    Anfernee Simons Over 2.5 -137.0
#
#         timestamp  bet_points  is_main  is_live  \
# 0    1.706313e+09        18.5     True    False
# 1    1.706313e+09        18.5     True    False
# 2    1.706313e+09        15.5     True    False
# 3    1.706313e+09        15.5     True    False
# 4    1.706313e+09        11.5     True    False
# ..            ...         ...      ...      ...
# 578  1.706312e+09         1.5     True    False
# 579  1.706285e+09         1.5     True    False
# 580  1.706285e+09         1.5     True    False
# 581  1.706285e+09         2.5     True    False
# 582  1.706285e+09         2.5     True    False
#
#                                     market_name  \
# 0    1st Half Player Fantasy Score (PrizePicks)
# 1    1st Half Player Fantasy Score (PrizePicks)
# 2    1st Half Player Fantasy Score (PrizePicks)
# 3    1st Half Player Fantasy Score (PrizePicks)
# 4    1st Half Player Fantasy Score (PrizePicks)
# ..                                          ...
# 578                            Player Turnovers
# 579                            Player Turnovers
# 580                            Player Turnovers
# 581                            Player Turnovers
# 582                            Player Turnovers
#
#                                         market  home_rotation_number  \
# 0    1st_half_player_fantasy_score_prizepicks_                   NaN
# 1    1st_half_player_fantasy_score_prizepicks_                   NaN
# 2    1st_half_player_fantasy_score_prizepicks_                   NaN
# 3    1st_half_player_fantasy_score_prizepicks_                   NaN
# 4    1st_half_player_fantasy_score_prizepicks_                   NaN
# ..                                         ...                   ...
# 578                           player_turnovers                   NaN
# 579                           player_turnovers                   NaN
# 580                           player_turnovers                   NaN
# 581                           player_turnovers                   NaN
# 582                           player_turnovers                   NaN
#
#      away_rotation_number deep_link_url     player_id        selection  \
# 0                     NaN          None  A08DF5DBBEE9  Anfernee Simons
# 1                     NaN          None  A08DF5DBBEE9  Anfernee Simons
# 2                     NaN          None  54818F8E80E9    Deandre Ayton
# 3                     NaN          None  54818F8E80E9    Deandre Ayton
# 4                     NaN          None  677724637AF2    Jabari Walker
# ..                    ...           ...           ...              ...
# 578                   NaN          None  54818F8E80E9    Deandre Ayton
# 579                   NaN          None  54818F8E80E9    Deandre Ayton
# 580                   NaN          None  54818F8E80E9    Deandre Ayton
# 581                   NaN          None  A08DF5DBBEE9  Anfernee Simons
# 582                   NaN          None  A08DF5DBBEE9  Anfernee Simons
#
#     normalized_selection selection_line  selection_points
# 0        anfernee_simons           over              18.5
# 1        anfernee_simons          under              18.5
# 2          deandre_ayton           over              15.5
# 3          deandre_ayton          under              15.5
# 4          jabari_walker           over              11.5
# ..                   ...            ...               ...
# 578        deandre_ayton          under               1.5
# 579        deandre_ayton          under               1.5
# 580        deandre_ayton           over               1.5
# 581      anfernee_simons          under               2.5
# 582      anfernee_simons           over               2.5
#
# [583 rows x 18 columns]

# %% [markdown]
# ### Organize The DF Into Something We Can Scan Easily

# %%
def create_cleaned_props_df(filtered_df):
    book_order = ["PrizePicks", "Underdog Fantasy", "Pinnacle", "FanDuel", "Draftkings", "BetMGM"]

    # Create a list to store our new rows
    cleaned_data = []

    # Group by 'market' and then by 'selection' within each group
    for market, market_df in filtered_df.groupby('market'):
        for selection in ['over', 'under']:
            row = {'Player Name': None, 'Selection': selection, 'Market Name': market}
            selection_present = False

            for book in book_order:
                book_df = market_df[(market_df['sports_book_name'] == book) & (market_df['selection_line'] == selection)]
                
                if not book_df.empty:
                    selection_present = True
                    # We assume that there's only one row for each book per selection
                    book_row = book_df.iloc[0]
                    row['Player Name'] = book_row['normalized_selection'].replace('_', ' ').title()
                    row[f'{book} Line Number'] = book_row['bet_points']
                    row[f'{book} Odds'] = book_row['price']
                else:
                    row[f'{book} Line Number'] = '-'
                    row[f'{book} Odds'] = '-'
            
            # If we found at least one entry for this selection, add the row to our list
            if selection_present:
                cleaned_data.append(row)

    # Convert the list of rows into a DataFrame
    cleaned_props_df = pd.DataFrame(cleaned_data)
    return cleaned_props_df

# Then you would call this function, passing the DataFrame you've obtained after applying the filter_for_prizepicks function:
# cleaned_props_df = create_cleaned_props_df(filtered_df)

# %% [markdown]
# ### For Each Player On A Team, Find All Player Props And Construct A Prop Line And Odds Comparion Table

# %%
cleaned_props_df = create_cleaned_props_df(filtered_odds_df)
display(cleaned_props_df)
# Out:
#         Player Name Selection                                  Market Name  \
# 0   Anfernee Simons      over    1st_half_player_fantasy_score_prizepicks_
# 1   Anfernee Simons     under    1st_half_player_fantasy_score_prizepicks_
# 2   Anfernee Simons      over                       1st_half_player_points
# 3   Anfernee Simons     under                       1st_half_player_points
# 4     Deandre Ayton      over  1st_half_player_points_+_rebounds_+_assists
# 5     Deandre Ayton     under  1st_half_player_points_+_rebounds_+_assists
# 6     Jabari Walker      over                               player_assists
# 7     Jabari Walker     under                               player_assists
# 8     Deandre Ayton      over                    player_defensive_rebounds
# 9     Deandre Ayton     under                    player_defensive_rebounds
# 10    Deandre Ayton      over             player_fantasy_score_prizepicks_
# 11    Jabari Walker     under             player_fantasy_score_prizepicks_
# 12  Anfernee Simons      over                 player_field_goals_attempted
# 13  Anfernee Simons     under                 player_field_goals_attempted
# 14  Anfernee Simons      over                      player_free_throws_made
# 15  Anfernee Simons     under                      player_free_throws_made
# 16  Anfernee Simons      over                           player_made_threes
# 17  Anfernee Simons     under                           player_made_threes
# 18  Anfernee Simons      over                                player_points
# 19    Jabari Walker     under                                player_points
# 20  Anfernee Simons      over                      player_points_+_assists
# 21  Anfernee Simons     under                      player_points_+_assists
# 22    Jabari Walker      over                     player_points_+_rebounds
# 23    Jabari Walker     under                     player_points_+_rebounds
# 24  Anfernee Simons      over           player_points_+_rebounds_+_assists
# 25  Anfernee Simons     under           player_points_+_rebounds_+_assists
# 26  Anfernee Simons      over                              player_rebounds
# 27  Anfernee Simons     under                              player_rebounds
# 28  Anfernee Simons      over                    player_rebounds_+_assists
# 29    Jabari Walker     under                    player_rebounds_+_assists
# 30  Anfernee Simons      over                      player_threes_attempted
# 31  Anfernee Simons     under                      player_threes_attempted
# 32    Jabari Walker      over                             player_turnovers
# 33    Jabari Walker     under                             player_turnovers
#
#     PrizePicks Line Number  PrizePicks Odds Underdog Fantasy Line Number  \
# 0                     18.5           -137.0                            -
# 1                     18.5           -137.0                            -
# 2                     12.5           -137.0                            -
# 3                     12.5           -137.0                            -
# 4                     13.5           -137.0                            -
# 5                     13.5           -137.0                            -
# 6                      5.5           -137.0                          5.5
# 7                      5.5           -137.0                          5.5
# 8                      7.0           -137.0                            -
# 9                      7.0           -137.0                            -
# 10                    31.0           -137.0                            -
# 11                    23.5           -137.0                            -
# 12                    19.0           -137.0                            -
# 13                    19.0           -137.0                            -
# 14                     3.5           -137.0                            -
# 15                     3.5           -137.0                            -
# 16                     3.5           -137.0                          3.5
# 17                     3.5           -137.0                          3.5
# 18                    24.5           -137.0                         24.5
# 19                    24.5           -137.0                         24.5
# 20                    11.5           -137.0                         30.5
# 21                    11.5           -137.0                         30.5
# 22                    18.5           -137.0                         18.5
# 23                    27.5           -137.0                         18.5
# 24                    20.5           -137.0                         20.5
# 25                    33.5           -137.0                         25.5
# 26                     8.0           -137.0                          3.5
# 27                     8.0           -137.0                          3.5
# 28                     9.5           -137.0                          9.5
# 29                     9.5           -137.0                         11.5
# 30                     9.0           -137.0                            -
# 31                     9.0           -137.0                            -
# 32                     1.5           -137.0                          1.5
# 33                     2.5           -137.0                          1.5
#
#    Underdog Fantasy Odds Pinnacle Line Number Pinnacle Odds  \
# 0                      -                    -             -
# 1                      -                    -             -
# 2                      -                    -             -
# 3                      -                    -             -
# 4                      -                    -             -
# 5                      -                    -             -
# 6                 -137.0                  5.5        -101.0
# 7                 -137.0                  5.5        -130.0
# 8                      -                    -             -
# 9                      -                    -             -
# 10                     -                    -             -
# 11                     -                    -             -
# 12                     -                    -             -
# 13                     -                    -             -
# 14                     -                    -             -
# 15                     -                    -             -
# 16                -137.0                  3.5         109.0
# 17                -137.0                  3.5        -143.0
# 18                -137.0                 10.5        -118.0
# 19                -137.0                 10.5        -112.0
# 20                -137.0                    -             -
# 21                -137.0                    -             -
# 22                -137.0                    -             -
# 23                -137.0                    -             -
# 24                -137.0                 33.5        -106.0
# 25                -137.0                 33.5        -124.0
# 26                -137.0                 10.5        -112.0
# 27                -137.0                 10.5        -118.0
# 28                -137.0                    -             -
# 29                -137.0                    -             -
# 30                     -                    -             -
# 31                     -                    -             -
# 32                -137.0                    -             -
# 33                -137.0                    -             -
#
#    FanDuel Line Number FanDuel Odds Draftkings Line Number Draftkings Odds  \
# 0                    -            -                      -               -
# 1                    -            -                      -               -
# 2                    -            -                      -               -
# 3                    -            -                      -               -
# 4                    -            -                      -               -
# 5                    -            -                      -               -
# 6                  7.5        330.0                      -               -
# 7                  5.5       -120.0                      -               -
# 8                    -            -                      -               -
# 9                    -            -                      -               -
# 10                   -            -                      -               -
# 11                   -            -                      -               -
# 12                   -            -                      -               -
# 13                   -            -                      -               -
# 14                   -            -                      -               -
# 15                   -            -                      -               -
# 16                 4.5        220.0                      -               -
# 17                 5.5       -900.0                      -               -
# 18                 9.5       -370.0                      -               -
# 19                10.5        200.0                      -               -
# 20                25.5       -290.0                      -               -
# 21                28.5        114.0                      -               -
# 22                29.5        260.0                      -               -
# 23                27.5      -1450.0                      -               -
# 24                39.5        265.0                      -               -
# 25                27.5        270.0                      -               -
# 26                 9.5       -155.0                      -               -
# 27                 9.5        124.0                      -               -
# 28                 6.5       -400.0                      -               -
# 29                13.5      -1450.0                      -               -
# 30                   -            -                      -               -
# 31                   -            -                      -               -
# 32                   -            -                      -               -
# 33                   -            -                      -               -
#
#    BetMGM Line Number BetMGM Odds
# 0                   -           -
# 1                   -           -
# 2                   -           -
# 3                   -           -
# 4                   -           -
# 5                   -           -
# 6                 1.5       180.0
# 7                 1.5      -250.0
# 8                   -           -
# 9                   -           -
# 10                  -           -
# 11                  -           -
# 12                  -           -
# 13                  -           -
# 14                  -           -
# 15                  -           -
# 16                3.5      -120.0
# 17                3.5      -110.0
# 18               24.5      -110.0
# 19               10.5      -110.0
# 20               30.5      -110.0
# 21               30.5      -120.0
# 22               18.5      -125.0
# 23               18.5      -105.0
# 24               33.5      -120.0
# 25               33.5      -110.0
# 26                3.5      -105.0
# 27                3.5      -125.0
# 28                9.5       100.0
# 29                9.5      -130.0
# 30                  -           -
# 31                  -           -
# 32                0.5      -250.0
# 33                0.5       175.0

# %% [markdown]
# ### For Each Player On A Team, Find All Player Props And Construct A Prop Line And Odds Comparion Table
