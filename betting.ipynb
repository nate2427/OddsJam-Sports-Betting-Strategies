# %% [markdown]
# # Sports Betting Data Cleaning Work Thru

# %% [markdown]
# ### Package Imports

# %%
from OddsJamClient import OddsJamClient;
from dotenv import load_dotenv
import os, requests, datetime, json
import pandas as pd

# %% [markdown]
# ### Load Env Vars

# %%
load_dotenv()
ODDSJAM_API_KEY = os.getenv("ODDSJAM_API_KEY")

# %% [markdown]
# ### Initialize Clients

# %%
Client = OddsJamClient(ODDSJAM_API_KEY);
Client.UseV2();

# %% [markdown]
# ### Get Games For Today

# %%
def get_nba_games_as_dataframe(league="nba", sport="basketball", game_date=None):
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/games'
    
    # Set up the headers with the API key and content type
    headers = {
        # 'x-api-key': ODDSJAM_API_KEY,
        'Content-Type': 'application/json'
    }

    if not game_date : 
        game_date = datetime.datetime.now().strftime('%Y-%m-%d')
    else:
        # Parse the string into a datetime object
        parsed_date = datetime.datetime.strptime(game_date, '%m/%d/%Y')
        # Format the datetime object to the desired string format
        game_date = parsed_date.strftime('%Y-%m-%d')

    
    # Set up the data payload with the parameters
    data = {
        'league': league,
        'sport': sport,
        "include_team_info": True,
        "key": ODDSJAM_API_KEY,
        "game_date": game_date
    }
    
    # Make the POST request to the API
    response = requests.get(end_point, headers=headers, params=data)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Here you would typically convert the response to a DataFrame
        df = pd.DataFrame(response.json()["data"])
        # update the time
        df['start_date'] = pd.to_datetime(df['start_date']).dt.strftime('%Y-%m-%d %H:%M:%S')
        df = df.sort_values(by='start_date').reset_index(drop=True)
        # Now, we extract the team ids from the home_team_info and away_team_info dictionaries
        # and then drop these columns from the DataFrame
        df['home_team_id'] = df['home_team_info'].apply(lambda x: x['id'])
        df['away_team_id'] = df['away_team_info'].apply(lambda x: x['id'])

        # Drop the now-redundant '_team_info' columns
        df = df.drop(columns=['home_team_info', 'away_team_info'])
        return df
    else:
        print(f"Error: {response.status_code}")
        # You could also handle errors here

# %%
games_df = get_nba_games_as_dataframe(league="NFL", sport="football", game_date="01/21/2024")

# %%
display(games_df)
# Out:
#                   id           start_date      home_team  \
# 0  21473-42288-24-03  2024-01-21 15:00:00  Detroit Lions
# 1  16341-13602-24-03  2024-01-21 18:30:00  Buffalo Bills
#
#               away_team  is_live  is_popular tournament    status     sport  \
# 0  Tampa Bay Buccaneers    False       False       None  unplayed  football
# 1    Kansas City Chiefs    False       False       None  unplayed  football
#
#   league  home_team_id  away_team_id
# 0    NFL  43412DC9CDCA  4E7DB4C57393
# 1    NFL  0787D09E47B9  2D71E5BA64A5

# %% [markdown]
# ### Segment The Games Into Sessions
# - Sessions are defined by games grouped together that start within 2 hours of each other
# - no two sessions will share the same game; they're all exclusive sessions.

# %%
def segment_games_into_sessions(games_df):
    # Ensure start_date is a datetime
    games_df['start_date'] = pd.to_datetime(games_df['start_date'])
    
    # Sort the games by start time
    sorted_games_df = games_df.sort_values(by='start_date').reset_index(drop=True)
    
    # List to hold all game sessions
    sessions = []
    # Temporary list to store games for the current session
    current_session = []
    # Start time of the current session
    session_start = None
    
    for _, game in sorted_games_df.iterrows():
        game_start = game['start_date']
        
        # If current session is empty or game starts within 2 hours of the session start
        if not current_session or (game_start - session_start).total_seconds() <= 2 * 3600:
            # Add game to current session
            current_session.append(game)
            # If this is the first game in the session, set the session start time
            if not session_start:
                session_start = game_start
        else:
            # If game starts more than 2 hours after the session start, save and reset the session
            sessions.append(current_session)
            current_session = [game]
            session_start = game_start
    
    # Add the last session if it exists
    if current_session:
        sessions.append(current_session)
    
    # Convert sessions to DataFrame list for better handling
    session_dfs = [pd.DataFrame(session) for session in sessions]
    
    return session_dfs

# %%
# Example usage:
# Assuming games_df is your DataFrame containing the games information.
segmented_sessions = segment_games_into_sessions(games_df)

# You can then access each session DataFrame with segmented_sessions[0], segmented_sessions[1], etc.
len(segmented_sessions)
# Out:
# 2

# %% [markdown]
# ### Get Players From A Specific Team

# %%
def get_players_from_specific_team(team_id: str, league="nba", sport="basketball") -> pd.DataFrame:
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/players/list'
    
    # Set up the headers with the API key
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Set up the parameters with the team_id
    params = {
        'team': team_id,
        'page': 3,
        # "league": league,
        # "sport": sport,
        'key': ODDSJAM_API_KEY
    }
    
    # Make the GET request to the API
    response = requests.get(end_point, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        data = response.json()["data"]
        df = pd.DataFrame(data)
        print(f'total pages: {response.json()["total_pages"]}')
        return df
    else:
        print(f"Error: {response.status_code}")
        return pd.DataFrame()

# %% [markdown]
# ### Testing That The Functionality Works As Envisioned
# * Need to get the game_id from the segmented_sessions

# %%
display(segmented_sessions[1])
# Out:
#                   id          start_date      home_team           away_team  \
# 1  16341-13602-24-03 2024-01-21 18:30:00  Buffalo Bills  Kansas City Chiefs
#
#    is_live  is_popular tournament    status     sport league  home_team_id  \
# 1    False       False       None  unplayed  football    NFL  0787D09E47B9
#
#    away_team_id
# 1  2D71E5BA64A5

# %%
get_players_from_specific_team(segmented_sessions[1].iloc[0]['home_team_id'])
# Out:
# total pages: 3
#               id        player_name   first_name   last_name      team_name  \
# 0   F0759E00A8F8     Reggie Gilliam       Reggie     Gilliam  Buffalo Bills
# 1   C59478DD4673      Reid Ferguson         Reid    Ferguson  Buffalo Bills
# 2   3F9E72899C9B   Richard Gouraige      Richard    Gouraige  Buffalo Bills
# 3   E7DFBA929108         Ryan Bates         Ryan       Bates  Buffalo Bills
# 4   7ED27A8A4CEF    Ryan Van Demark         Ryan  Van Demark  Buffalo Bills
# 5   07711AE256A9         Sam Martin          Sam      Martin  Buffalo Bills
# 6   56092A533E33     Shane Buechele        Shane    Buechele  Buffalo Bills
# 7   4774DD3E29D4        Shaq Lawson         Shaq      Lawson  Buffalo Bills
# 8   DCE161EE1CF4         Siran Neal        Siran        Neal  Buffalo Bills
# 9   EAEF11EE9618      Spencer Brown      Spencer       Brown  Buffalo Bills
# 10  71572A1F8C20       Stefon Diggs       Stefon       Diggs  Buffalo Bills
# 11  6E5204307437      Taron Johnson        Taron     Johnson  Buffalo Bills
# 12  26696768CE43        Taylor Rapp       Taylor        Rapp  Buffalo Bills
# 13  4DBBDF4018AD     Terrel Bernard       Terrel     Bernard  Buffalo Bills
# 14  DA0414FCBB14         Tim Settle          Tim      Settle  Buffalo Bills
# 15  84F25A4B5981        Tommy Doyle        Tommy       Doyle  Buffalo Bills
# 16  BF23E744E848  Tre'Davious White  Tre'Davious       White  Buffalo Bills
# 17  09051EF701E4       Tre' McKitty         Tre'     McKitty  Buffalo Bills
# 18  3C39CECCDDD5    Trent Sherfield        Trent   Sherfield  Buffalo Bills
# 19  C315B63E625D         Ty Johnson           Ty     Johnson  Buffalo Bills
# 20  D821F3334D06         Tyler Bass        Tyler        Bass  Buffalo Bills
# 21  F4D3A3DBB747   Tyler Matakevich        Tyler  Matakevich  Buffalo Bills
# 22  039E156652DE       Tyrel Dodson        Tyrel      Dodson  Buffalo Bills
# 23  6C4C34F7CDC3     Tyrell Shavers       Tyrell     Shavers  Buffalo Bills
# 24  8E967666C90E         Von Miller          Von      Miller  Buffalo Bills
#
#          team_id number position age height  weight  is_active     sport  \
# 0   0787D09E47B9     41       FB  26     72     244       True  football
# 1   0787D09E47B9     69       LS  29     74     235       True  football
# 2   0787D09E47B9     75       OT  25     77     308       True  football
# 3   0787D09E47B9     71        G  26     76     302       True  football
# 4   0787D09E47B9     74       OT  25     78     307       True  football
# 5   0787D09E47B9      8        P  33     73     205       True  football
# 6   0787D09E47B9      6       QB  26     72     210       True  football
# 7   0787D09E47B9     90       DE  29     75     265       True  football
# 8   0787D09E47B9     33       CB  29     72     206       True  football
# 9   0787D09E47B9     79       OT  25     80     311       True  football
# 10  0787D09E47B9     14       WR  30     72     191       True  football
# 11  0787D09E47B9      7       CB  27     71     192       True  football
# 12  0787D09E47B9     20        S  26     72     208       True  football
# 13  0787D09E47B9     43       LB  24     73     224       True  football
# 14  0787D09E47B9     99       DT  26     75     313       True  football
# 15  0787D09E47B9     72       OT  25     80     320       True  football
# 16  0787D09E47B9     27       CB  29     71     192       True  football
# 17  0787D09E47B9     88       TE  25     76     246       True  football
# 18  0787D09E47B9     16       WR  27     73     219       True  football
# 19  0787D09E47B9     26       RB  26     70     210       True  football
# 20  0787D09E47B9      2       PK  26     70     183       True  football
# 21  0787D09E47B9     44       LB  31     73     235       True  football
# 22  0787D09E47B9     25       LB  25     72     237       True  football
# 23  0787D09E47B9     80       WR  24     78     210       True  football
# 24  0787D09E47B9     40       LB  34     75     250       True  football
#
#    league
# 0     NFL
# 1     NFL
# 2     NFL
# 3     NFL
# 4     NFL
# 5     NFL
# 6     NFL
# 7     NFL
# 8     NFL
# 9     NFL
# 10    NFL
# 11    NFL
# 12    NFL
# 13    NFL
# 14    NFL
# 15    NFL
# 16    NFL
# 17    NFL
# 18    NFL
# 19    NFL
# 20    NFL
# 21    NFL
# 22    NFL
# 23    NFL
# 24    NFL

# %%
temp = get_players_from_specific_team(segmented_sessions[1].iloc[0]['away_team_id'])
# Out:
# total pages: 4

# %%
temp
# Out:
#               id          player_name   first_name    last_name  \
# 0   923C0B6110CD         Matt Bushman         Matt      Bushman
# 1   868B02CBC42F       Matt Dickerson         Matt    Dickerson
# 2   7ECC86914BEF   Mecole Hardman Jr.       Mecole  Hardman Jr.
# 3   658E9A4ADAA9        Mike Caliendo         Mike     Caliendo
# 4   6BE925261591           Mike Danna         Mike        Danna
# 5   00071ACF8666         Mike Edwards         Mike      Edwards
# 6   6C2367F28691      Mike Pennel Jr.         Mike   Pennel Jr.
# 7   0615B45C311E  Montrell Washington     Montrell   Washington
# 8   269A362F5C64       Nazeeh Johnson       Nazeeh      Johnson
# 9   8B72DF4A5554         Neil Farrell         Neil      Farrell
# 10  A0D7440EC1DF            Nic Jones          Nic        Jones
# 11  9E40A6E6C639      Nick Allegretti         Nick   Allegretti
# 12  8B4BFB32C420          Nick Bolton         Nick       Bolton
# 13  9AA9917F5E02        Nikko Remigio        Nikko      Remigio
# 14  DE86A90D0B9A            Noah Gray         Noah         Gray
# 15  B671C99CB711      Patrick Mahomes      Patrick      Mahomes
# 16  F707A8FA3B10  Prince Tega Wanogho  Prince Tega      Wanogho
# 17  D5BE2AF21C8F          Rashee Rice       Rashee         Rice
# 18  64945FEDDEE3         Richie James       Richie        James
# 19  219F0E558088           Skyy Moore         Skyy        Moore
# 20  3553D4FD6CD7     Tershawn Wharton     Tershawn      Wharton
# 21  177E7C529829       Tommy Townsend        Tommy     Townsend
# 22  A7EC5CA607D1         Travis Kelce       Travis        Kelce
# 23  3505E26D774B       Trent McDuffie        Trent     McDuffie
# 24  9FD1709712B6            Trey Dean         Trey         Dean
#
#              team_name       team_id number position age height  weight  \
# 0   Kansas City Chiefs  2D71E5BA64A5     49       TE  28     77     245
# 1   Kansas City Chiefs  2D71E5BA64A5     93       DT  28     77     292
# 2   Kansas City Chiefs  2D71E5BA64A5     12       WR  25     70     187
# 3   Kansas City Chiefs  2D71E5BA64A5     66        G  26     76     301
# 4   Kansas City Chiefs  2D71E5BA64A5     51       DE  26     74     257
# 5   Kansas City Chiefs  2D71E5BA64A5     21        S  27     70     205
# 6   Kansas City Chiefs  2D71E5BA64A5     69       DT  32     76     332
# 7   Kansas City Chiefs  2D71E5BA64A5     12       WR  24     70     170
# 8   Kansas City Chiefs  2D71E5BA64A5     13        S  25     70     199
# 9   Kansas City Chiefs  2D71E5BA64A5     92       DE  25     76     325
# 10  Kansas City Chiefs  2D71E5BA64A5     31       CB  22     72     189
# 11  Kansas City Chiefs  2D71E5BA64A5     73        G  27     76     310
# 12  Kansas City Chiefs  2D71E5BA64A5     32       LB  23     71     237
# 13  Kansas City Chiefs  2D71E5BA64A5     27       WR  24     69     187
# 14  Kansas City Chiefs  2D71E5BA64A5     83       TE  24     75     240
# 15  Kansas City Chiefs  2D71E5BA64A5     15       QB  28     74     225
# 16  Kansas City Chiefs  2D71E5BA64A5     76       OT  26     77     308
# 17  Kansas City Chiefs  2D71E5BA64A5      4       WR  23     73     204
# 18  Kansas City Chiefs  2D71E5BA64A5     17       WR  28     69     185
# 19  Kansas City Chiefs  2D71E5BA64A5     24       WR  23     70     195
# 20  Kansas City Chiefs  2D71E5BA64A5     98       DT  25     73     280
# 21  Kansas City Chiefs  2D71E5BA64A5      5        P  27     73     191
# 22  Kansas City Chiefs  2D71E5BA64A5     87       TE  34     77     250
# 23  Kansas City Chiefs  2D71E5BA64A5     22       CB  23     71     193
# 24  Kansas City Chiefs  2D71E5BA64A5   None        S  23     74     200
#
#     is_active     sport league
# 0        True  football    NFL
# 1        True  football    NFL
# 2        True  football    NFL
# 3        True  football    NFL
# 4        True  football    NFL
# 5        True  football    NFL
# 6        True  football    NFL
# 7        True  football    NFL
# 8        True  football    NFL
# 9        True  football    NFL
# 10       True  football    NFL
# 11       True  football    NFL
# 12       True  football    NFL
# 13       True  football    NFL
# 14       True  football    NFL
# 15       True  football    NFL
# 16       True  football    NFL
# 17       True  football    NFL
# 18       True  football    NFL
# 19       True  football    NFL
# 20       True  football    NFL
# 21       True  football    NFL
# 22       True  football    NFL
# 23       True  football    NFL
# 24       True  football    NFL

# %% [markdown]
# ### Get All Available Player Props For Each Team, Given There's A PrizePicks Line

# %%
def get_player_odds(player_id: str, sportsbook: list, league="nba", sport="basketball") -> pd.DataFrame:
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/game-odds'
    
    # Set up the headers with the API key
    headers = {
        'Content-Type': 'application/json'
    }
    # Set up the parameters with the team_id
    params = {
        'player_id': player_id,
        "sportsbook": sportsbook,
        # "league": league,
        # "sport": sport,
        'key': ODDSJAM_API_KEY
    }
    
    # Make the GET request to the API
    response = requests.get(end_point, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        data = response.json()["data"]
        df = pd.DataFrame(data)
        return df
    else:
        print(f"Error: {response.reason}")
        print(response)
        return pd.DataFrame()

# %% [markdown]
# ### Test That The Function Pulls Odds Correctly

# %%
odds = get_player_odds("64945FEDDEE3", ["PrizePicks", "Underdog Fantasy", "Pinnacle", "FanDuel", "Draftkings", "BetMGM"])

# %%
odds.shape
# Out:
# (1, 11)

# %%
books = odds.iloc[0].odds
books
# Out:
# [{'id': '66EA5D95A677',
#   'sports_book_name': 'Underdog Fantasy',
#   'name': 'Richie James Over 5.5',
#   'price': -137.0,
#   'timestamp': 1705799006.9842653,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 5.5},
#  {'id': 'E405402D4C66',
#   'sports_book_name': 'Underdog Fantasy',
#   'name': 'Richie James Under 5.5',
#   'price': -137.0,
#   'timestamp': 1705799006.98432,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'under',
#   'selection_points': 5.5},
#  {'id': '16341-13602-24-03:pinnacle:anytime_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr.',
#   'price': 714.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Anytime Touchdown Scorer',
#   'market': 'anytime_touchdown_scorer',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:pinnacle:player_receiving_yards:richie_james_jr_over_4_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Over 4.5',
#   'price': -124.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 4.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 4.5},
#  {'id': '16341-13602-24-03:pinnacle:player_receiving_yards:richie_james_jr_under_4_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Under 4.5',
#   'price': -106.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 4.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'under',
#   'selection_points': 4.5},
#  {'id': '16341-13602-24-03:pinnacle:player_receptions:richie_james_jr_over_0_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Over 0.5',
#   'price': -187.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:pinnacle:player_receptions:richie_james_jr_under_0_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Under 0.5',
#   'price': 137.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:pinnacle:player_touchdowns:richie_james_jr_over_0_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Over 0.5',
#   'price': 714.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:pinnacle:player_touchdowns:richie_james_jr_under_0_5',
#   'sports_book_name': 'Pinnacle',
#   'name': 'Richie James Jr. Under 0.5',
#   'price': -2757.0,
#   'timestamp': 1705786403.4901135,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': 318.0,
#   'away_rotation_number': 317.0,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:betmgm:anytime_touchdown_scorer:richie_james',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James',
#   'price': 1000.0,
#   'timestamp': 1705594675.818969,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Anytime Touchdown Scorer',
#   'market': 'anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1049995975--1252043024&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:betmgm:first_touchdown_scorer:richie_james',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James',
#   'price': 5000.0,
#   'timestamp': 1705767589.1173353,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Touchdown Scorer',
#   'market': 'first_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1049995972--1252043117&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:betmgm:last_touchdown_scorer:richie_james',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James',
#   'price': 4000.0,
#   'timestamp': 1705594675.818969,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Last Touchdown Scorer',
#   'market': 'last_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1049995981--1252042890&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:betmgm:player_receiving_yards:richie_james_over_5_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Over 5.5',
#   'price': -110.0,
#   'timestamp': 1705798989.3305688,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1052041128--1246683838&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 5.5},
#  {'id': '16341-13602-24-03:betmgm:player_receiving_yards:richie_james_under_5_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Under 5.5',
#   'price': -120.0,
#   'timestamp': 1705798989.3305688,
#   'bet_points': 5.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1052041128--1246683837&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'under',
#   'selection_points': 5.5},
#  {'id': '16341-13602-24-03:betmgm:player_receptions:richie_james_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Over 0.5',
#   'price': -185.0,
#   'timestamp': 1705770718.4159157,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1052041335--1246683259&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:betmgm:player_receptions:richie_james_under_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Under 0.5',
#   'price': 135.0,
#   'timestamp': 1705788263.105162,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1052041335--1246683258&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:betmgm:player_touchdowns:richie_james_over_0_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Over 0.5',
#   'price': 1000.0,
#   'timestamp': 1705594675.818969,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1049995975--1252043024&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:betmgm:player_touchdowns:richie_james_over_1_5',
#   'sports_book_name': 'BetMGM',
#   'name': 'Richie James Over 1.5',
#   'price': 25000.0,
#   'timestamp': 1705786852.9981525,
#   'bet_points': 1.5,
#   'is_main': False,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sports.<STATE>.betmgm.com/en/sports?options=15280645-1049995977--1252042963&type=Single',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': 'E94DA1B15B5D',
#   'sports_book_name': 'PrizePicks',
#   'name': 'Richie James Over 8.5',
#   'price': -137.0,
#   'timestamp': 1705802163.305765,
#   'bet_points': 8.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 8.5},
#  {'id': '299D373734F8',
#   'sports_book_name': 'PrizePicks',
#   'name': 'Richie James Under 8.5',
#   'price': -137.0,
#   'timestamp': 1705802163.3057792,
#   'bet_points': 8.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receiving Yards',
#   'market': 'player_receiving_yards',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': None,
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'under',
#   'selection_points': 8.5},
#  {'id': '16341-13602-24-03:fanduel:1st_half_anytime_touchdown_scorer:richie_james',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James',
#   'price': 1600.0,
#   'timestamp': 1705798538.2921317,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': '1st Half Anytime Touchdown Scorer',
#   'market': '1st_half_anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803249&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:fanduel:2nd_half_anytime_touchdown_scorer:richie_james',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James',
#   'price': 1700.0,
#   'timestamp': 1705798148.3251166,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': '2nd Half Anytime Touchdown Scorer',
#   'market': '2nd_half_anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803250&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:fanduel:anytime_touchdown_scorer:richie_james',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James',
#   'price': 1000.0,
#   'timestamp': 1705788580.55604,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Anytime Touchdown Scorer',
#   'market': 'anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803246&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:fanduel:first_touchdown_scorer:richie_james',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James',
#   'price': 4000.0,
#   'timestamp': 1705774529.3208601,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Touchdown Scorer',
#   'market': 'first_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803242&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:fanduel:last_touchdown_scorer:richie_james',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James',
#   'price': 3900.0,
#   'timestamp': 1705798148.3251166,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Last Touchdown Scorer',
#   'market': 'last_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803245&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:fanduel:player_touchdowns:richie_james_over_0_5',
#   'sports_book_name': 'FanDuel',
#   'name': 'Richie James Over 0.5',
#   'price': 1000.0,
#   'timestamp': 1705788580.55604,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.fanduel.com/addToBetslip?marketId[0]=42.411803246&selectionId[0]=20534950',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James',
#   'normalized_selection': 'richie_james',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:draftkings:1st_half_anytime_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 1300.0,
#   'timestamp': 1705770187.0339043,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': '1st Half Anytime Touchdown Scorer',
#   'market': '1st_half_anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343672%231701507560_13L88808Q1-1825872719Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:1st_quarter_anytime_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 2500.0,
#   'timestamp': 1705770187.0339043,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': '1st Quarter Anytime Touchdown Scorer',
#   'market': '1st_quarter_anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343666%231701507266_13L88808Q1-1118566040Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:2nd_half_anytime_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 1200.0,
#   'timestamp': 1705761985.189722,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': '2nd Half Anytime Touchdown Scorer',
#   'market': '2nd_half_anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343662%231701507226_13L88808Q11622869014Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:anytime_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 800.0,
#   'timestamp': 1705773562.0458066,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Anytime Touchdown Scorer',
#   'market': 'anytime_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343660%231701507498_13L88808Q11383322939Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:first_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 4000.0,
#   'timestamp': 1705773606.828377,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'First Touchdown Scorer',
#   'market': 'first_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343663%231701507431_13L88808Q1-2098150088Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:last_touchdown_scorer:richie_james_jr_',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr.',
#   'price': 4500.0,
#   'timestamp': 1705612400.273392,
#   'bet_points': None,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Last Touchdown Scorer',
#   'market': 'last_touchdown_scorer',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343668%231701507382_13L88808Q1-713300763Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': None,
#   'selection_points': None},
#  {'id': '16341-13602-24-03:draftkings:player_receptions:richie_james_jr_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr. Over 0.5',
#   'price': -175.0,
#   'timestamp': 1705770667.0285563,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180875019%231704531991_13L88808Q12026604767Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:draftkings:player_receptions:richie_james_jr_under_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr. Under 0.5',
#   'price': 135.0,
#   'timestamp': 1705770667.0285563,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Receptions',
#   'market': 'player_receptions',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180875019%231704531990_13L88808Q1-1406754358Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'under',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:draftkings:player_touchdowns:richie_james_jr_over_0_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr. Over 0.5',
#   'price': 800.0,
#   'timestamp': 1705773562.0458066,
#   'bet_points': 0.5,
#   'is_main': True,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343660%231701507498_13L88808Q11383322939Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 0.5},
#  {'id': '16341-13602-24-03:draftkings:player_touchdowns:richie_james_jr_over_1_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr. Over 1.5',
#   'price': 10000.0,
#   'timestamp': 1705606833.1814795,
#   'bet_points': 1.5,
#   'is_main': False,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343673%231701507591_13L88808Q112816641Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 1.5},
#  {'id': '16341-13602-24-03:draftkings:player_touchdowns:richie_james_jr_over_2_5',
#   'sports_book_name': 'DraftKings',
#   'name': 'Richie James Jr. Over 2.5',
#   'price': 25000.0,
#   'timestamp': 1705773562.0458066,
#   'bet_points': 2.5,
#   'is_main': False,
#   'is_live': False,
#   'market_name': 'Player Touchdowns',
#   'market': 'player_touchdowns',
#   'home_rotation_number': None,
#   'away_rotation_number': None,
#   'deep_link_url': 'https://sportsbook.draftkings.com/event/29977723?outcomes=0QA180343671%231701507546_13L88808Q11129263848Q20',
#   'player_id': '64945FEDDEE3',
#   'selection': 'Richie James Jr.',
#   'normalized_selection': 'richie_james_jr_',
#   'selection_line': 'over',
#   'selection_points': 2.5}]

# %%
books_df = pd.DataFrame(books)
display(books_df.head())
print(books_df.shape)
# Out:
#                                                   id  sports_book_name  \
# 0                                       66EA5D95A677  Underdog Fantasy
# 1                                       E405402D4C66  Underdog Fantasy
# 2  16341-13602-24-03:pinnacle:anytime_touchdown_s...          Pinnacle
# 3  16341-13602-24-03:pinnacle:player_receiving_ya...          Pinnacle
# 4  16341-13602-24-03:pinnacle:player_receiving_ya...          Pinnacle
#
#                          name  price     timestamp  bet_points  is_main  \
# 0       Richie James Over 5.5 -137.0  1.705799e+09         5.5     True
# 1      Richie James Under 5.5 -137.0  1.705799e+09         5.5     True
# 2            Richie James Jr.  714.0  1.705786e+09         NaN     True
# 3   Richie James Jr. Over 4.5 -124.0  1.705786e+09         4.5     True
# 4  Richie James Jr. Under 4.5 -106.0  1.705786e+09         4.5     True
#
#    is_live               market_name                    market  \
# 0    False    Player Receiving Yards    player_receiving_yards
# 1    False    Player Receiving Yards    player_receiving_yards
# 2    False  Anytime Touchdown Scorer  anytime_touchdown_scorer
# 3    False    Player Receiving Yards    player_receiving_yards
# 4    False    Player Receiving Yards    player_receiving_yards
#
#    home_rotation_number  away_rotation_number deep_link_url     player_id  \
# 0                   NaN                   NaN          None  64945FEDDEE3
# 1                   NaN                   NaN          None  64945FEDDEE3
# 2                 318.0                 317.0          None  64945FEDDEE3
# 3                 318.0                 317.0          None  64945FEDDEE3
# 4                 318.0                 317.0          None  64945FEDDEE3
#
#           selection normalized_selection selection_line  selection_points
# 0      Richie James         richie_james           over               5.5
# 1      Richie James         richie_james          under               5.5
# 2  Richie James Jr.     richie_james_jr_           None               NaN
# 3  Richie James Jr.     richie_james_jr_           over               4.5
# 4  Richie James Jr.     richie_james_jr_          under               4.5
# (37, 18)

# %% [markdown]
# ### Create Cleaned Sportsbook Data Frame
# * Each row will have PrizePicks and show the odds and the line for a couple other highly trusted Sportsbooks.
# * This makes it seemless to compare PrizePicks Player Projections to the sentiment of the trusted market.

# %%
def filter_for_prizepicks(odds_df):
    # First, sort the DataFrame by the 'market' column, which acts as our unique key.
    sorted_odds_df = odds_df.sort_values(by='market')

    # Group by 'market' to organize our DataFrame into groups based on prediction types.
    grouped = sorted_odds_df.groupby('market')

    # Now, we will keep only the groups that contain at least one 'PrizePicks' entry.
    valid_groups = []
    for name, group in grouped:
        if 'PrizePicks' in group['sports_book_name'].values:
            valid_groups.append(group)
    if len(valid_groups) > 0:
        # Combine all valid groups back into a DataFrame.
        filtered_df = pd.concat(valid_groups)
        filtered_df = filtered_df.groupby(['market', 'sports_book_name']).apply(lambda x: x.reset_index(drop=True)).reset_index(drop=True)
    else:
        filtered_df = pd.DataFrame()
    
    return filtered_df

# %% [markdown]
# ### Testing the functionality

# %%
filtered_odds_df = filter_for_prizepicks(books_df)
# Out:
# /var/folders/w0/s93bsfj93rqdl5944srjtn9c0000gn/T/ipykernel_13218/2737534077.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   filtered_df = filtered_df.groupby(['market', 'sports_book_name']).apply(lambda x: x.reset_index(drop=True)).reset_index(drop=True)

# %%
filtered_odds_df
# Out:
#                                                   id  sports_book_name  \
# 0  16341-13602-24-03:betmgm:player_receiving_yard...            BetMGM
# 1  16341-13602-24-03:betmgm:player_receiving_yard...            BetMGM
# 2  16341-13602-24-03:pinnacle:player_receiving_ya...          Pinnacle
# 3  16341-13602-24-03:pinnacle:player_receiving_ya...          Pinnacle
# 4                                       299D373734F8        PrizePicks
# 5                                       E94DA1B15B5D        PrizePicks
# 6                                       66EA5D95A677  Underdog Fantasy
# 7                                       E405402D4C66  Underdog Fantasy
#
#                          name  price     timestamp  bet_points  is_main  \
# 0      Richie James Under 5.5 -120.0  1.705799e+09         5.5     True
# 1       Richie James Over 5.5 -110.0  1.705799e+09         5.5     True
# 2   Richie James Jr. Over 4.5 -124.0  1.705786e+09         4.5     True
# 3  Richie James Jr. Under 4.5 -106.0  1.705786e+09         4.5     True
# 4      Richie James Under 8.5 -137.0  1.705802e+09         8.5     True
# 5       Richie James Over 8.5 -137.0  1.705802e+09         8.5     True
# 6       Richie James Over 5.5 -137.0  1.705799e+09         5.5     True
# 7      Richie James Under 5.5 -137.0  1.705799e+09         5.5     True
#
#    is_live             market_name                  market  \
# 0    False  Player Receiving Yards  player_receiving_yards
# 1    False  Player Receiving Yards  player_receiving_yards
# 2    False  Player Receiving Yards  player_receiving_yards
# 3    False  Player Receiving Yards  player_receiving_yards
# 4    False  Player Receiving Yards  player_receiving_yards
# 5    False  Player Receiving Yards  player_receiving_yards
# 6    False  Player Receiving Yards  player_receiving_yards
# 7    False  Player Receiving Yards  player_receiving_yards
#
#    home_rotation_number  away_rotation_number  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                 318.0                 317.0
# 3                 318.0                 317.0
# 4                   NaN                   NaN
# 5                   NaN                   NaN
# 6                   NaN                   NaN
# 7                   NaN                   NaN
#
#                                        deep_link_url     player_id  \
# 0  https://sports.<STATE>.betmgm.com/en/sports?op...  64945FEDDEE3
# 1  https://sports.<STATE>.betmgm.com/en/sports?op...  64945FEDDEE3
# 2                                               None  64945FEDDEE3
# 3                                               None  64945FEDDEE3
# 4                                               None  64945FEDDEE3
# 5                                               None  64945FEDDEE3
# 6                                               None  64945FEDDEE3
# 7                                               None  64945FEDDEE3
#
#           selection normalized_selection selection_line  selection_points
# 0      Richie James         richie_james          under               5.5
# 1      Richie James         richie_james           over               5.5
# 2  Richie James Jr.     richie_james_jr_           over               4.5
# 3  Richie James Jr.     richie_james_jr_          under               4.5
# 4      Richie James         richie_james          under               8.5
# 5      Richie James         richie_james           over               8.5
# 6      Richie James         richie_james           over               5.5
# 7      Richie James         richie_james          under               5.5

# %% [markdown]
# ### Organize The DF Into Something We Can Scan Easily

# %%
def create_cleaned_props_df(filtered_df):
    book_order = ["PrizePicks", "Underdog Fantasy", "Pinnacle", "FanDuel", "Draftkings", "BetMGM"]

    # This will hold the cleaned rows
    cleaned_rows = []

    # Group by market to consider each prop bet separately
    for market, market_group in filtered_df.groupby('market'):
        # For each market, we further group by 'selection' to separate 'over' and 'under'
        for selection, selection_group in market_group.groupby('selection'):
            # Initialize the row with the player name, selection, and market
            row = {
                'Player Name': selection_group['name'].iloc[0].split()[0],
                'Selection': selection,
                'Market Name': market
            }

            # For each sportsbook, get the corresponding odds and line number
            for book in book_order:
                book_group = selection_group[selection_group['sports_book_name'] == book]
                
                if not book_group.empty:
                    # There should be only one entry per book per selection ('over'/'under') per market
                    book_entry = book_group.iloc[0]
                    row[f'{book} Line Number'] = book_entry['bet_points']
                    row[f'{book} Odds'] = book_entry['price']
                else:
                    # If a book does not have an entry, we represent this as None
                    row[f'{book} Line Number'] = None
                    row[f'{book} Odds'] = None

            # Add the constructed row to our list of cleaned rows
            cleaned_rows.append(row)

    # Convert the list of dictionaries to a DataFrame
    cleaned_props_df = pd.DataFrame(cleaned_rows)

    return cleaned_props_df

# %%
# Usage example:
cleaned_props_df = create_cleaned_props_df(filtered_odds_df)
display(cleaned_props_df)
# Out:
#   Player Name         Selection             Market Name  \
# 0      Richie      Richie James  player_receiving_yards
# 1      Richie  Richie James Jr.  player_receiving_yards
#
#    PrizePicks Line Number  PrizePicks Odds  Underdog Fantasy Line Number  \
# 0                     8.5           -137.0                           5.5
# 1                     NaN              NaN                           NaN
#
#    Underdog Fantasy Odds  Pinnacle Line Number  Pinnacle Odds  \
# 0                 -137.0                   NaN            NaN
# 1                    NaN                   4.5         -124.0
#
#   FanDuel Line Number FanDuel Odds Draftkings Line Number Draftkings Odds  \
# 0                None         None                   None            None
# 1                None         None                   None            None
#
#    BetMGM Line Number  BetMGM Odds
# 0                 5.5       -120.0
# 1                 NaN          NaN

# %%
def test_other_books_presence(original_df, filtered_df):
    # Get all the markets present in the filtered DataFrame
    filtered_markets = filtered_df['market'].unique()
    
    # Check for each market, if there are entries for other books in the original DataFrame
    missing_books = {}
    for market in filtered_markets:
        books_in_market = original_df[original_df['market'] == market]['sports_book_name'].unique()
        missing_books_in_market = [book for book in books_in_market if book != 'PrizePicks']
        if missing_books_in_market:
            missing_books[market] = missing_books_in_market

    # If the missing_books dictionary is empty, it means there are no other book entries for the markets we have.
    # Otherwise, it will list which markets have entries from other books.
    return missing_books

# %%
# Usage:
# 'books_df' is the DataFrame before filtering and 'filtered_odds_df' is after filtering.
missing_books = test_other_books_presence(books_df, filtered_odds_df)
# if empty, then we didnt miss any
print(missing_books)
# Out:
# ['player_minutes_played']
# {}
