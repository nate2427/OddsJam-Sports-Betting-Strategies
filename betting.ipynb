# %% [markdown]
# # Sports Betting Data Cleaning Work Thru

# %% [markdown]
# ### Package Imports

# %%
from OddsJamClient import OddsJamClient;
from dotenv import load_dotenv
import os, requests, datetime, json
import pandas as pd

# %% [markdown]
# ### Load Env Vars

# %%
load_dotenv()
ODDSJAM_API_KEY = os.getenv("ODDSJAM_API_KEY")

# %% [markdown]
# ### Initialize Clients

# %%
Client = OddsJamClient(ODDSJAM_API_KEY);
Client.UseV2();

# %% [markdown]
# ### Get Games For Today

# %%
def get_nba_games_as_dataframe(league="nba", sport="basketball"):
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/games'
    
    # Set up the headers with the API key and content type
    headers = {
        # 'x-api-key': ODDSJAM_API_KEY,
        'Content-Type': 'application/json'
    }
    
    # Set up the data payload with the parameters
    data = {
        'league': league,
        'sport': sport,
        "include_team_info": True,
        "key": ODDSJAM_API_KEY,
        "game_date": datetime.datetime.now().strftime('%Y-%m-%d')
    }
    
    # Make the POST request to the API
    response = requests.get(end_point, headers=headers, params=data)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Here you would typically convert the response to a DataFrame
        df = pd.DataFrame(response.json()["data"])
        # update the time
        df['start_date'] = pd.to_datetime(df['start_date']).dt.strftime('%Y-%m-%d %H:%M:%S')
        df = df.sort_values(by='start_date').reset_index(drop=True)
        # Now, we extract the team ids from the home_team_info and away_team_info dictionaries
        # and then drop these columns from the DataFrame
        df['home_team_id'] = df['home_team_info'].apply(lambda x: x['id'])
        df['away_team_id'] = df['away_team_info'].apply(lambda x: x['id'])

        # Drop the now-redundant '_team_info' columns
        df = df.drop(columns=['home_team_info', 'away_team_info'])
        return df
    else:
        print(f"Error: {response.status_code}")
        # You could also handle errors here

# %%
games_df = get_nba_games_as_dataframe()

# %%
display(games_df)
# Out:
#                        id           start_date               home_team  \
# 0  25236-12967-2024-01-20  2024-01-20 15:00:00         Detroit Pistons
# 1  32634-30886-2024-01-20  2024-01-20 19:00:00      Washington Wizards
# 2  35142-48840-2024-01-20  2024-01-20 19:00:00       Charlotte Hornets
# 3  19957-11464-2024-01-20  2024-01-20 19:30:00           Atlanta Hawks
# 4  40294-35775-2024-01-20  2024-01-20 19:30:00         New York Knicks
# 5  17844-40177-2024-01-20  2024-01-20 20:00:00         Houston Rockets
# 6  37132-22796-2024-01-20  2024-01-20 20:00:00           Chicago Bulls
# 7  41811-19432-2024-01-20  2024-01-20 20:00:00  Minnesota Timberwolves
#
#                away_team  is_live  is_popular tournament    status  \
# 0        Milwaukee Bucks    False       False       None  unplayed
# 1      San Antonio Spurs    False       False       None  unplayed
# 2     Philadelphia 76ers    False       False       None  unplayed
# 3    Cleveland Cavaliers    False       False       None  unplayed
# 4        Toronto Raptors    False       False       None  unplayed
# 5              Utah Jazz    False       False       None  unplayed
# 6      Memphis Grizzlies    False       False       None  unplayed
# 7  Oklahoma City Thunder    False       False       None  unplayed
#
#         sport league  home_team_id  away_team_id
# 0  basketball    NBA  5988658C6B9B  14682EF45C4D
# 1  basketball    NBA  8F17F23FB753  E89F51275352
# 2  basketball    NBA  C65360931346  EDF03AD3C346
# 3  basketball    NBA  B59C1C735494  D5348BDFEBCC
# 4  basketball    NBA  6A36E386117E  417F4FFF4625
# 5  basketball    NBA  DF2D9E9E8E20  7C902BB2E272
# 6  basketball    NBA  CA98E3A931AE  2C653B0A5BBF
# 7  basketball    NBA  FDAE71FA88C6  D8EC6878976A

# %% [markdown]
# ### Segment The Games Into Sessions
# - Sessions are defined by games grouped together that start within 2 hours of each other
# - no two sessions will share the same game; they're all exclusive sessions.

# %%
def segment_games_into_sessions(games_df):
    # Ensure start_date is a datetime
    games_df['start_date'] = pd.to_datetime(games_df['start_date'])
    
    # Sort the games by start time
    sorted_games_df = games_df.sort_values(by='start_date').reset_index(drop=True)
    
    # List to hold all game sessions
    sessions = []
    # Temporary list to store games for the current session
    current_session = []
    # Start time of the current session
    session_start = None
    
    for _, game in sorted_games_df.iterrows():
        game_start = game['start_date']
        
        # If current session is empty or game starts within 2 hours of the session start
        if not current_session or (game_start - session_start).total_seconds() <= 2 * 3600:
            # Add game to current session
            current_session.append(game)
            # If this is the first game in the session, set the session start time
            if not session_start:
                session_start = game_start
        else:
            # If game starts more than 2 hours after the session start, save and reset the session
            sessions.append(current_session)
            current_session = [game]
            session_start = game_start
    
    # Add the last session if it exists
    if current_session:
        sessions.append(current_session)
    
    # Convert sessions to DataFrame list for better handling
    session_dfs = [pd.DataFrame(session) for session in sessions]
    
    return session_dfs

# %%
# Example usage:
# Assuming games_df is your DataFrame containing the games information.
segmented_sessions = segment_games_into_sessions(games_df)

# You can then access each session DataFrame with segmented_sessions[0], segmented_sessions[1], etc.
len(segmented_sessions)
# Out:
# 2

# %% [markdown]
# ### Get Players From A Specific Team

# %%
def get_players_from_specific_team(team_id: str, league="nba", sport="basketball") -> pd.DataFrame:
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/players/list'
    
    # Set up the headers with the API key
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Set up the parameters with the team_id
    params = {
        'team': team_id,
        # "league": league,
        # "sport": sport,
        'key': ODDSJAM_API_KEY
    }
    
    # Make the GET request to the API
    response = requests.get(end_point, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        data = response.json()["data"]
        df = pd.DataFrame(data)
        return df
    else:
        print(f"Error: {response.status_code}")
        return pd.DataFrame()

# %% [markdown]
# ### Testing That The Functionality Works As Envisioned
# * Need to get the game_id from the segmented_sessions

# %%
display(segmented_sessions[1])
# Out:
#                        id          start_date               home_team  \
# 1  32634-30886-2024-01-20 2024-01-20 19:00:00      Washington Wizards
# 2  35142-48840-2024-01-20 2024-01-20 19:00:00       Charlotte Hornets
# 3  19957-11464-2024-01-20 2024-01-20 19:30:00           Atlanta Hawks
# 4  40294-35775-2024-01-20 2024-01-20 19:30:00         New York Knicks
# 5  17844-40177-2024-01-20 2024-01-20 20:00:00         Houston Rockets
# 6  37132-22796-2024-01-20 2024-01-20 20:00:00           Chicago Bulls
# 7  41811-19432-2024-01-20 2024-01-20 20:00:00  Minnesota Timberwolves
#
#                away_team  is_live  is_popular tournament    status  \
# 1      San Antonio Spurs    False       False       None  unplayed
# 2     Philadelphia 76ers    False       False       None  unplayed
# 3    Cleveland Cavaliers    False       False       None  unplayed
# 4        Toronto Raptors    False       False       None  unplayed
# 5              Utah Jazz    False       False       None  unplayed
# 6      Memphis Grizzlies    False       False       None  unplayed
# 7  Oklahoma City Thunder    False       False       None  unplayed
#
#         sport league  home_team_id  away_team_id
# 1  basketball    NBA  8F17F23FB753  E89F51275352
# 2  basketball    NBA  C65360931346  EDF03AD3C346
# 3  basketball    NBA  B59C1C735494  D5348BDFEBCC
# 4  basketball    NBA  6A36E386117E  417F4FFF4625
# 5  basketball    NBA  DF2D9E9E8E20  7C902BB2E272
# 6  basketball    NBA  CA98E3A931AE  2C653B0A5BBF
# 7  basketball    NBA  FDAE71FA88C6  D8EC6878976A

# %%
get_players_from_specific_team(segmented_sessions[1].iloc[0]['home_team_id'])
# Out:
# 8F17F23FB753
#               id          player_name first_name    last_name  \
# 0   DBA7A36A56A0         Anthony Gill    Anthony         Gill
# 1   CBD44E0BCC61      Bilal Coulibaly      Bilal    Coulibaly
# 2   D714BB639EFB        Corey Kispert      Corey      Kispert
# 3   8A7EB4769E41       Daniel Gafford     Daniel      Gafford
# 4   EC65ADA7CB14         Delon Wright      Delon       Wright
# 5   A516E172A7D9          Deni Avdija       Deni       Avdija
# 6   909D4FE4E8CC       Eugene Omoruyi     Eugene      Omoruyi
# 7   3A9B0B8E64F9       Hamidou Diallo    Hamidou       Diallo
# 8   AEB008271151        Isaiah Livers     Isaiah       Livers
# 9   458D5626316C         Jared Butler      Jared       Butler
# 10  7DA11610D10E         Johnny Davis     Johnny        Davis
# 11  88CBA982B68D         Jordan Poole     Jordan        Poole
# 12  F74F11119A08        Jules Bernard      Jules      Bernard
# 13  2F80F21FE649           Kyle Kuzma       Kyle        Kuzma
# 14  785466EEC7ED        Landry Shamet     Landry       Shamet
# 15  077D7F3D9F77    Marvin Bagley III     Marvin   Bagley III
# 16  F8126C4371F7  Patrick Baldwin Jr.    Patrick  Baldwin Jr.
# 17  D354D0E8C6B3           Tyus Jones       Tyus        Jones
#
#              team_name       team_id number position age height  weight  \
# 0   Washington Wizards  8F17F23FB753     16       PF  32     80     230
# 1   Washington Wizards  8F17F23FB753      0       SG  20     80     194
# 2   Washington Wizards  8F17F23FB753     24       SG  25     79     220
# 3   Washington Wizards  8F17F23FB753     21        C  26     82     233
# 4   Washington Wizards  8F17F23FB753     55       PG  32     77     183
# 5   Washington Wizards  8F17F23FB753      8       SF  23     81     220
# 6   Washington Wizards  8F17F23FB753     97       SF  27     78     235
# 7   Washington Wizards  8F17F23FB753      6       SG  26     77     198
# 8   Washington Wizards  8F17F23FB753     12       SF  26     79     230
# 9   Washington Wizards  8F17F23FB753      4       SG  24     75     195
# 10  Washington Wizards  8F17F23FB753      1       SG  22     77     194
# 11  Washington Wizards  8F17F23FB753     13       SG  25     76     195
# 12  Washington Wizards  8F17F23FB753     14       SG  24     79     210
# 13  Washington Wizards  8F17F23FB753     33       PF  29     80     220
# 14  Washington Wizards  8F17F23FB753     20       SG  27     76     190
# 15  Washington Wizards  8F17F23FB753     35       PF  25     83     234
# 16  Washington Wizards  8F17F23FB753      7       SF  22     81     220
# 17  Washington Wizards  8F17F23FB753      5       PG  28     72     184
#
#     is_active       sport league
# 0        True  basketball    NBA
# 1        True  basketball    NBA
# 2        True  basketball    NBA
# 3        True  basketball    NBA
# 4        True  basketball    NBA
# 5        True  basketball    NBA
# 6        True  basketball    NBA
# 7        True  basketball    NBA
# 8        True  basketball    NBA
# 9        True  basketball    NBA
# 10       True  basketball    NBA
# 11       True  basketball    NBA
# 12       True  basketball    NBA
# 13       True  basketball    NBA
# 14       True  basketball    NBA
# 15       True  basketball    NBA
# 16       True  basketball    NBA
# 17       True  basketball    NBA

# %%
temp = get_players_from_specific_team(segmented_sessions[1].iloc[0]['away_team_id'])
# Out:
# E89F51275352

# %%
temp
# Out:
#               id            player_name first_name       last_name  \
# 0   7959261438C7           Blake Wesley      Blake          Wesley
# 1   97294E569CB7             Cedi Osman       Cedi           Osman
# 2   CD99BB67884D         Charles Bassey    Charles          Bassey
# 3   E10320F559B1         David Duke Jr.      David        Duke Jr.
# 4   804B793FEEDB          Devin Vassell      Devin         Vassell
# 5   AACF1CBA1094        Devonte' Graham   Devonte'          Graham
# 6   17624A972445        Dominick Barlow   Dominick          Barlow
# 7   CA04B2FDE9C2         Doug McDermott       Doug       McDermott
# 8   80FFC6ED3456          Jeremy Sochan     Jeremy          Sochan
# 9   99318830CCC3      Julian Champagnie     Julian      Champagnie
# 10  F34EFECEA2DA         Keldon Johnson     Keldon         Johnson
# 11  98A54A13BDB9         Malaki Branham     Malaki         Branham
# 12  B904B59F7593         Mamadi Diakite     Mamadi         Diakite
# 13  9FC0FB04CE9A  Sandro Mamukelashvili     Sandro  Mamukelashvili
# 14  E31B2A490250           Sidy Cissoko       Sidy         Cissoko
# 15  D45700C1F1BD              Tre Jones        Tre           Jones
# 16  ECE70FF020E8      Victor Wembanyama     Victor      Wembanyama
# 17  00238C40718B           Zach Collins       Zach         Collins
#
#             team_name       team_id number position age height  weight  \
# 0   San Antonio Spurs  E89F51275352     14       SG  21     77     181
# 1   San Antonio Spurs  E89F51275352     16       SG  29     79     215
# 2   San Antonio Spurs  E89F51275352     28        C  24     83     235
# 3   San Antonio Spurs  E89F51275352      7       SG  25     76     205
# 4   San Antonio Spurs  E89F51275352     24       SG  24     79     194
# 5   San Antonio Spurs  E89F51275352      4       SG  29     73     185
# 6   San Antonio Spurs  E89F51275352     26       SF  21     81     214
# 7   San Antonio Spurs  E89F51275352     17       PF  32     79     225
# 8   San Antonio Spurs  E89F51275352     10       PF  21     81     230
# 9   San Antonio Spurs  E89F51275352     30       SF  23     80     215
# 10  San Antonio Spurs  E89F51275352      3       SF  25     77     211
# 11  San Antonio Spurs  E89F51275352     22       SG  21     77     180
# 12  San Antonio Spurs  E89F51275352     29       PF  27     81     224
# 13  San Antonio Spurs  E89F51275352     54        C  25     83     240
# 14  San Antonio Spurs  E89F51275352     25       SF  20     80     200
# 15  San Antonio Spurs  E89F51275352     33       PG  24     75     185
# 16  San Antonio Spurs  E89F51275352      1       PF  20     88     210
# 17  San Antonio Spurs  E89F51275352     23       PF  27     83     235
#
#     is_active       sport league
# 0        True  basketball    NBA
# 1        True  basketball    NBA
# 2        True  basketball    NBA
# 3        True  basketball    NBA
# 4        True  basketball    NBA
# 5        True  basketball    NBA
# 6        True  basketball    NBA
# 7        True  basketball    NBA
# 8        True  basketball    NBA
# 9        True  basketball    NBA
# 10       True  basketball    NBA
# 11       True  basketball    NBA
# 12       True  basketball    NBA
# 13       True  basketball    NBA
# 14       True  basketball    NBA
# 15       True  basketball    NBA
# 16       True  basketball    NBA
# 17       True  basketball    NBA

# %% [markdown]
# ### Get All Available Player Props For Each Team, Given There's A PrizePicks Line

# %%
def get_player_odds(player_id: str, sportsbook: list, league="nba", sport="basketball") -> pd.DataFrame:
    # Define the endpoint URL
    end_point = 'https://api-external.oddsjam.com/api/v2/game-odds'
    
    # Set up the headers with the API key
    headers = {
        'Content-Type': 'application/json'
    }
    # Set up the parameters with the team_id
    params = {
        'player_id': player_id,
        "sportsbook": sportsbook,
        # "league": league,
        # "sport": sport,
        'key': ODDSJAM_API_KEY
    }
    
    # Make the GET request to the API
    response = requests.get(end_point, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the JSON response to a DataFrame
        data = response.json()["data"]
        print(response.json())
        df = pd.DataFrame(data)
        return df
    else:
        print(f"Error: {response.reason}")
        print(response)
        return pd.DataFrame()

# %% [markdown]
# ### Test That The Function Pulls Odds Correctly

# %%
odds = get_player_odds("2F80F21FE649", ["PrizePicks", "Underdog Fantasy", "Pinnacle", "FanDuel", "Draftkings", "BetMGM"])
# Out:
# {'data': [{'id': '54023-30886-2024-01-21', 'start_date': '2024-01-21T23:00:00+00:00', 'home_team': 'Washington Wizards', 'away_team': 'Denver Nuggets', 'is_live': False, 'is_popular': False, 'tournament': None, 'status': 'unplayed', 'sport': 'basketball', 'league': 'NBA', 'odds': []}, {'id': '32634-30886-2024-01-20', 'start_date': '2024-01-21T00:00:00+00:00', 'home_team': 'Washington Wizards', 'away_team': 'San Antonio Spurs', 'is_live': False, 'is_popular': False, 'tournament': None, 'status': 'unplayed', 'sport': 'basketball', 'league': 'NBA', 'odds': [{'id': '946C1EC66BC7', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Over 4.5', 'price': -137.0, 'timestamp': 1705779507.1105263, 'bet_points': 4.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Assists', 'market': 'player_assists', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'over', 'selection_points': 4.5}, {'id': '26DBC6C0BFF0', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Under 4.5', 'price': -137.0, 'timestamp': 1705779507.1105561, 'bet_points': 4.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Assists', 'market': 'player_assists', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'under', 'selection_points': 4.5}, {'id': '7CF436F02863', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Over 21.5', 'price': -137.0, 'timestamp': 1705790486.9465544, 'bet_points': 21.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Points', 'market': 'player_points', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'over', 'selection_points': 21.5}, {'id': '293D9A0DD9F6', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Under 21.5', 'price': -137.0, 'timestamp': 1705790486.9467654, 'bet_points': 21.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Points', 'market': 'player_points', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'under', 'selection_points': 21.5}, {'id': '1EEDAE48FA5D', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Over 25.5', 'price': -137.0, 'timestamp': 1705779507.1109617, 'bet_points': 25.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Points + Assists', 'market': 'player_points_+_assists', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'over', 'selection_points': 25.5}, {'id': '2C9F084FF26F', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Under 25.5', 'price': -137.0, 'timestamp': 1705779507.1109915, 'bet_points': 25.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Points + Assists', 'market': 'player_points_+_assists', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'selection_line': 'under', 'selection_points': 25.5}, {'id': 'E0864B02D8DC', 'sports_book_name': 'Underdog Fantasy', 'name': 'Kyle Kuzma Over 29.5', 'price': -137.0, 'timestamp': 1705790007.1855998, 'bet_points': 29.5, 'is_main': True, 'is_live': False, 'market_name': 'Player Points + Rebounds', 'market': 'player_points_+_rebounds', 'home_rotation_number': None, 'away_rotation_number': None, 'deep_link_url': None, 'player_id': '2F80F21FE649', 'selection': 'Kyle Kuzma', 'normalized_selection': 'kyle_kuzma', 'se ...

# %%
odds.shape
# Out:
# (2, 11)

# %%
books = odds.iloc[1].odds

# %%
books_df = pd.DataFrame(books)
display(books_df.head())
print(books_df.shape)
# Out:
#              id  sports_book_name                   name  price     timestamp  \
# 0  946C1EC66BC7  Underdog Fantasy    Kyle Kuzma Over 4.5 -137.0  1.705780e+09
# 1  26DBC6C0BFF0  Underdog Fantasy   Kyle Kuzma Under 4.5 -137.0  1.705780e+09
# 2  7CF436F02863  Underdog Fantasy   Kyle Kuzma Over 21.5 -137.0  1.705790e+09
# 3  293D9A0DD9F6  Underdog Fantasy  Kyle Kuzma Under 21.5 -137.0  1.705790e+09
# 4  1EEDAE48FA5D  Underdog Fantasy   Kyle Kuzma Over 25.5 -137.0  1.705780e+09
#
#    bet_points  is_main  is_live              market_name  \
# 0         4.5     True    False           Player Assists
# 1         4.5     True    False           Player Assists
# 2        21.5     True    False            Player Points
# 3        21.5     True    False            Player Points
# 4        25.5     True    False  Player Points + Assists
#
#                     market  home_rotation_number  away_rotation_number  \
# 0           player_assists                   NaN                   NaN
# 1           player_assists                   NaN                   NaN
# 2            player_points                   NaN                   NaN
# 3            player_points                   NaN                   NaN
# 4  player_points_+_assists                   NaN                   NaN
#
#   deep_link_url     player_id   selection normalized_selection selection_line  \
# 0          None  2F80F21FE649  Kyle Kuzma           kyle_kuzma           over
# 1          None  2F80F21FE649  Kyle Kuzma           kyle_kuzma          under
# 2          None  2F80F21FE649  Kyle Kuzma           kyle_kuzma           over
# 3          None  2F80F21FE649  Kyle Kuzma           kyle_kuzma          under
# 4          None  2F80F21FE649  Kyle Kuzma           kyle_kuzma           over
#
#    selection_points
# 0               4.5
# 1               4.5
# 2              21.5
# 3              21.5
# 4              25.5
# (275, 18)
